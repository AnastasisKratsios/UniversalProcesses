# %% [markdown]
# ---
#
# # Generic Conditional Laws for Random-Fields - via:
#
# ## Universal $\mathcal{P}_1(\mathbb{R})$-Deep Neural Model (Type A)
#
# ---
#
# By: [Anastasis Kratsios](https://people.math.ethz.ch/~kratsioa/) - 2021.

# %% [markdown]
# ---

# %% [markdown]
# # Training Algorithm:
# ---
# ## 1) Generate Data:
# Generates the empirical measure $\sum_{n=1}^N \delta_{X_T(\omega_n)}$ of $X_T$ conditional on $X_0=x_0\in \mathbb{R}$ *($x_0$ and $T>0$ are user-provided)*.
#
# ## 2) Get "Sample Barycenters":
# Let $\{\mu_n\}_{n=1}^N\subset\mathcal{P}_1(\mathbb{R}^d)$.  Then, the *sample barycenter* is defined by:
# 1. $\mathcal{M}^{(0)}\triangleq \left\{\hat{\mu}_n\right\}_{n=1}^N$,
# 2. For $1\leq n\leq \mbox{N sample barycenters}$:
#     - $
# \mu^{\star}\in \underset{\tilde{\mu}\in \mathcal{M}^{(n)}}{\operatorname{argmin}}\, \sum_{n=1}^N \mathcal{W}_1\left(\mu^{\star},\mu_n\right),
# $
#     - $\mathcal{M}^{(n)}\triangleq \mathcal{M}^{(n-1)} - \{\mu^{\star}\},$
# *i.e., the closest generated measure form the random sample to all other elements of the random sample.*
#
# ---
# **Note:** *We simplify the computational burden of getting the correct classes by putting this right into this next loop.*
#
# ## 3) Train Deep Classifier:
# $\hat{f}\in \operatorname{argmin}_{f \in \mathcal{NN}_{d:N}^{\star}}
# \sum_{x \in \mathbb{X}}
# \,
# \mathbb{H}
# \left(
#     \operatorname{Softmax}_N\circ f(x)_n| I\left\{W_1(\hat{\mu}_n,\mu_x),\inf_{m\leq N} W_1(\hat{\mu}_m,\mu_x)\right\}
# \right);
# $
# where $\mathbb{H}$ is the categorical cross-entropy.
#
# ---
# ---
# ---
# ## Notes - Why the procedure is so computationally efficient?
# ---
#  - The sample barycenters do not require us to solve for any new Wasserstein-1 Barycenters; which is much more computationally costly,
#  - Our training procedure never back-propages through $\mathcal{W}_1$ since steps 2 and 3 are full-decoupled.  Therefore, training our deep classifier is (comparatively) cheap since it takes values in the standard $N$-simplex.
#
# ---

# %% [markdown]
# ## Meta-Parameters

# %% [markdown]
# ### Simulation

# %% [markdown]
# #### Ground Truth:
# *The build-in Options:*
# - rSDE
# - pfBM
# - 2lnflow

# %%
# Option 1:
# groud_truth = "rSDE"
# Option 2:
groud_truth = "2lnflow"
## Option 3:
# groud_truth = "pfBM"

# %% [markdown]
# #### Grid Hyperparameter(s)

# %%
## Monte-Carlo
N_Euler_Maruyama_Steps = 10*2
N_Monte_Carlo_Samples = 10**2
N_Monte_Carlo_Samples_Test = 10**3 # How many MC-samples to draw from test-set?

# End times for Time-Grid
T_end = 1
T_end_test = 1.1


## Grid
N_Grid_Finess = 10*2
Max_Grid = 0.5
x_0 = 1

# Number of Centers (\hat{\mu}_s)
N_Quantizers_to_parameterize = 10**2

# %% [markdown]
# This option sets $\delta$ in $B_{\mathbb{R}\times [0,\infty)}(\hat{x}_n,\delta)$; where $\hat{x}_n\in \nu_{\cdot}^{-1}[\hat{\mu}]$.  N_measures_per_center sets the number of samples to draw in this ball...by construction the training set is $\delta$-bounded and $\nu_{(x,t)}$, for any such $x$ is $\omega_{\nu_{\cdot}}(\delta)$-bounded in $\mathcal{P}_1(\mathbb{R})$.

# %%
# Hyper-parameters of Cover
delta = 0.1
N_measures_per_center = 100

# %% [markdown]
# **Note**: Setting *N_Quantizers_to_parameterize* prevents any barycenters and sub-sampling.

# %% [markdown]
# #### Mode: Code-Testin Parameter(s)
# - True: $\Rightarrow$ cross validation through grid of very mild parameters just to test hardward or software.
# - False: $\Rightarrow$ run CV-grid.

# %%
trial_run = True

# %% [markdown]
# ### Meta-parameters
# Ratio $\frac{\text{Testing Datasize}}{\text{Training Datasize}}$.

# %%
test_size_ratio = .25

# %% [markdown]
# ## Simulation from Rough SDE
# Simulate via Euler-M method from:
# $$
# X_T^x = x + \int_0^T \alpha(s,X_s^x)ds + \int_0^T((1-\eta)\beta(s,X_s^s)+\eta\sigma_s^H)dW_s.
# $$

# %% [markdown]
# ### Drift

# %%
def alpha(t,x):
    return np.sin(math.pi*t)

# %% [markdown]
# ### Volatility

# %%
def beta(t,x):
    return x

# %% [markdown]
# ### Roughness Meta-parameters
#  - Roughness is $H$,
#  - Ratio_fBM_to_typical_vol is $\eta$.

# %%
Rougness = 0.9 # Hurst Parameter
Ratio_fBM_to_typical_vol = 0.5 # $\eta$ in equation above.

# %% [markdown]
# ## Simulation from Measure-Valued $2$-Parameter Log-Gaussian Flow
# $$
# X_{t,x} \sim \log\text{-}\mathcal{N}\left(\alpha(t,x),\beta(t,x)\right).
# $$

# %% [markdown]
# **Note:** *$\alpha$ and $\beta$ are specified below in the SDE Example*.

# %%
# Run Backend
# %run Universal_Processes_Trainer_BACKEND.ipynb
exec(open('Universal_Processes_Trainer_BACKEND.py').read())
# Out:
# Using TensorFlow backend.
#  36%|███▌      | 36/100 [00:00<00:00, 352.40it/s]
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# Building Training Set - 2-logNormal Ground-Truth
# 100%|██████████| 100/100 [00:00<00:00, 232.81it/s]
# 100%|██████████| 10/10 [00:00<00:00, 3415.28it/s]
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Building Test Set - 2-logNormal Ground-Truth
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# ==========================================
# Training Classifer Portion of Type-A Model
# ==========================================
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:  1.8min remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:  1.8min finished
# Epoch 1/200
# 316/316 [==============================] - 1s 2ms/step - loss: 3.0130 - accuracy: 0.1766
# Epoch 2/200
# 316/316 [==============================] - 1s 3ms/step - loss: 1.4280 - accuracy: 0.4834
# Epoch 3/200
# 316/316 [==============================] - 1s 3ms/step - loss: 1.0492 - accuracy: 0.6050
# Epoch 4/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.8877 - accuracy: 0.6605
# Epoch 5/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.8188 - accuracy: 0.6749
# Epoch 6/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.7091 - accuracy: 0.7236
# Epoch 7/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.6657 - accuracy: 0.7355
# Epoch 8/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.6508 - accuracy: 0.7361
# Epoch 9/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.6334 - accuracy: 0.7493
# Epoch 10/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.6151 - accuracy: 0.7515
# Epoch 11/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.5632 - accuracy: 0.7709
# Epoch 12/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.5638 - accuracy: 0.7697
# Epoch 13/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.5505 - accuracy: 0.7740
# Epoch 14/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.5098 - accuracy: 0.7909
# Epoch 15/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7806
# Epoch 16/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.5168 - accuracy: 0.7906
# Epoch 17/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.5066 - accuracy: 0.7901
# Epoch 18/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.5118 - accuracy: 0.7938
# Epoch 19/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4906 - accuracy: 0.7992
# Epoch 20/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4685 - accuracy: 0.8083
# Epoch 21/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.5000 - accuracy: 0.7943
# Epoch 22/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4536 - accuracy: 0.8136
# Epoch 23/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4509 - accuracy: 0.8143
# Epoch 24/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4319 - accuracy: 0.8235
# Epoch 25/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4439 - accuracy: 0.8177
# Epoch 26/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4489 - accuracy: 0.8158
# Epoch 27/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4602 - accuracy: 0.8113
# Epoch 28/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4146 - accuracy: 0.8285
# Epoch 29/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4305 - accuracy: 0.8233
# Epoch 30/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4236 - accuracy: 0.8277
# Epoch 31/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8355
# Epoch 32/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4453 - accuracy: 0.8157
# Epoch 33/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4152 - accuracy: 0.8289
# Epoch 34/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4104 - accuracy: 0.8275
# Epoch 35/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.4221 - accuracy: 0.8251
# Epoch 36/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3861 - accuracy: 0.8389
# Epoch 37/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3917 - accuracy: 0.8380
# Epoch 38/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4084 - accuracy: 0.8292
# Epoch 39/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4062 - accuracy: 0.8305
# Epoch 40/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3814 - accuracy: 0.8391
# Epoch 41/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3618 - accuracy: 0.8499
# Epoch 42/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3973 - accuracy: 0.8340
# Epoch 43/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.8516
# Epoch 44/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3968 - accuracy: 0.8379
# Epoch 45/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3847 - accuracy: 0.8410
# Epoch 46/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3471 - accuracy: 0.8549
# Epoch 47/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3546 - accuracy: 0.8515
# Epoch 48/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3770 - accuracy: 0.8435
# Epoch 49/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3842 - accuracy: 0.8445
# Epoch 50/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.3726 - accuracy: 0.8469
# Epoch 51/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.3388 - accuracy: 0.8571
# Epoch 52/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3694 - accuracy: 0.8457
# Epoch 53/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3660 - accuracy: 0.8478
# Epoch 54/200
# 316/316 [==============================] - 1s 5ms/step - loss: 0.3509 - accuracy: 0.8569
# Epoch 55/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3407 - accuracy: 0.8575
# Epoch 56/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3609 - accuracy: 0.8482
# Epoch 57/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.3307 - accuracy: 0.8629
# Epoch 58/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.3507 - accuracy: 0.8566
# Epoch 59/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.3428 - accuracy: 0.8577
# Epoch 60/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.3611 - accuracy: 0.8476
# Epoch 61/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3109 - accuracy: 0.8700
# Epoch 62/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.3426 - accuracy: 0.8566
# Epoch 63/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3404 - accuracy: 0.8590
# Epoch 64/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3385 - accuracy: 0.8622
# Epoch 65/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3575 - accuracy: 0.8537
# Epoch 66/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3267 - accuracy: 0.8627
# Epoch 67/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3389 - accuracy: 0.8592
# Epoch 68/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3543 - accuracy: 0.8498
# Epoch 69/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3065 - accuracy: 0.8688
# Epoch 70/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3333 - accuracy: 0.8637
# Epoch 71/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2896 - accuracy: 0.8790
# Epoch 72/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3333 - accuracy: 0.8623
# Epoch 73/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3169 - accuracy: 0.8669
# Epoch 74/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3136 - accuracy: 0.8701
# Epoch 75/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3124 - accuracy: 0.8688
# Epoch 76/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3208 - accuracy: 0.8680
# Epoch 77/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3056 - accuracy: 0.8717
# Epoch 78/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2996 - accuracy: 0.8746
# Epoch 79/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3599 - accuracy: 0.8523
# Epoch 80/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2971 - accuracy: 0.8750
# Epoch 81/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2967 - accuracy: 0.8780
# Epoch 82/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3205 - accuracy: 0.8655
# Epoch 83/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2844 - accuracy: 0.8782
# Epoch 84/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2978 - accuracy: 0.8742
# Epoch 85/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3212 - accuracy: 0.8653
# Epoch 86/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2862 - accuracy: 0.8810
# Epoch 87/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2991 - accuracy: 0.8762
# Epoch 88/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2916 - accuracy: 0.8807
# Epoch 89/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3178 - accuracy: 0.8712
# Epoch 90/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2936 - accuracy: 0.8765
# Epoch 91/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2757 - accuracy: 0.8842
# Epoch 92/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2735 - accuracy: 0.8858
# Epoch 93/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3208 - accuracy: 0.8669
# Epoch 94/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2997 - accuracy: 0.8753
# Epoch 95/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2855 - accuracy: 0.8804
# Epoch 96/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3021 - accuracy: 0.8754
# Epoch 97/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2817 - accuracy: 0.8833
# Epoch 98/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3051 - accuracy: 0.8732
# Epoch 99/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2681 - accuracy: 0.8870
# Epoch 100/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2772 - accuracy: 0.8843
# Epoch 101/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2861 - accuracy: 0.8823
# Epoch 102/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2711 - accuracy: 0.8891
# Epoch 103/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2929 - accuracy: 0.8801
# Epoch 104/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2677 - accuracy: 0.8933
# Epoch 105/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3082 - accuracy: 0.8771
# Epoch 106/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2749 - accuracy: 0.8826
# Epoch 107/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2810 - accuracy: 0.8855
# Epoch 108/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2933 - accuracy: 0.8776
# Epoch 109/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2430 - accuracy: 0.8968
# Epoch 110/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2613 - accuracy: 0.8905
# Epoch 111/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2867 - accuracy: 0.8802
# Epoch 112/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2929 - accuracy: 0.8787
# Epoch 113/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2795 - accuracy: 0.8856
# Epoch 114/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2740 - accuracy: 0.8861
# Epoch 115/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2715 - accuracy: 0.8875
# Epoch 116/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2748 - accuracy: 0.8823
# Epoch 117/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2841 - accuracy: 0.8831
# Epoch 118/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2819 - accuracy: 0.8818
# Epoch 119/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2430 - accuracy: 0.8962
# Epoch 120/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2582 - accuracy: 0.8887
# Epoch 121/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2658 - accuracy: 0.8921
# Epoch 122/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2487 - accuracy: 0.8966
# Epoch 123/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2540 - accuracy: 0.8962
# Epoch 124/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2808 - accuracy: 0.8843
# Epoch 125/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2647 - accuracy: 0.8908
# Epoch 126/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2778 - accuracy: 0.8849
# Epoch 127/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2580 - accuracy: 0.8918
# Epoch 128/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2881 - accuracy: 0.8835
# Epoch 129/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2545 - accuracy: 0.8946
# Epoch 130/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2799 - accuracy: 0.8879
# Epoch 131/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2650 - accuracy: 0.8902
# Epoch 132/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2555 - accuracy: 0.8961
# Epoch 133/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2729 - accuracy: 0.8856
# Epoch 134/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2609 - accuracy: 0.8949
# Epoch 135/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2353 - accuracy: 0.9035
# Epoch 136/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2432 - accuracy: 0.8980
# Epoch 137/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2865 - accuracy: 0.8844
# Epoch 138/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2865 - accuracy: 0.8850
# Epoch 139/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2528 - accuracy: 0.8948
# Epoch 140/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2447 - accuracy: 0.8962
# Epoch 141/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2519 - accuracy: 0.8963
# Epoch 142/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2756 - accuracy: 0.8869
# Epoch 143/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2585 - accuracy: 0.8921
# Epoch 144/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2486 - accuracy: 0.8936
# Epoch 145/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2490 - accuracy: 0.8972
# Epoch 146/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2523 - accuracy: 0.8950
# Epoch 147/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2671 - accuracy: 0.8870
# Epoch 148/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2655 - accuracy: 0.8920
# Epoch 149/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2544 - accuracy: 0.8939
# Epoch 150/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2731 - accuracy: 0.8864
# Epoch 151/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2377 - accuracy: 0.9034
# Epoch 152/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2727 - accuracy: 0.8906
# Epoch 153/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2307 - accuracy: 0.9069
# Epoch 154/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2373 - accuracy: 0.9034
# Epoch 155/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2667 - accuracy: 0.8896
# Epoch 156/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2515 - accuracy: 0.8949
# Epoch 157/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2450 - accuracy: 0.8961
# Epoch 158/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2405 - accuracy: 0.8993
# Epoch 159/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2427 - accuracy: 0.8949
# Epoch 160/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2781 - accuracy: 0.8861
# Epoch 161/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2616 - accuracy: 0.8927
# Epoch 162/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2549 - accuracy: 0.8961
# Epoch 163/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2304 - accuracy: 0.9034
# Epoch 164/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2580 - accuracy: 0.8918
# Epoch 165/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2260 - accuracy: 0.9042
# Epoch 166/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2212 - accuracy: 0.9081
# Epoch 167/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2445 - accuracy: 0.8961
# Epoch 168/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2355 - accuracy: 0.9036
# Epoch 169/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2357 - accuracy: 0.9005
# Epoch 170/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2442 - accuracy: 0.8981
# Epoch 171/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2685 - accuracy: 0.8895
# Epoch 172/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2295 - accuracy: 0.9034
# Epoch 173/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2416 - accuracy: 0.9026
# Epoch 174/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2316 - accuracy: 0.9010
# Epoch 175/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2485 - accuracy: 0.8966
# Epoch 176/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2576 - accuracy: 0.8907
# Epoch 177/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2316 - accuracy: 0.9069
# Epoch 178/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2249 - accuracy: 0.9046
# Epoch 179/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2564 - accuracy: 0.8966
# Epoch 180/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2207 - accuracy: 0.9068
# Epoch 181/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2399 - accuracy: 0.9037
# Epoch 182/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2499 - accuracy: 0.8978
# Epoch 183/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2245 - accuracy: 0.9087
# Epoch 184/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2240 - accuracy: 0.9064
# Epoch 185/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2382 - accuracy: 0.9025
# Epoch 186/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2449 - accuracy: 0.8984
# Epoch 187/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2338 - accuracy: 0.9023
# Epoch 188/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2304 - accuracy: 0.9007
# Epoch 189/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2216 - accuracy: 0.9057
# Epoch 190/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2439 - accuracy: 0.8990
# Epoch 191/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2492 - accuracy: 0.8978
# Epoch 192/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2194 - accuracy: 0.9115
# Epoch 193/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2182 - accuracy: 0.9062
# Epoch 194/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2650 - accuracy: 0.8940
# Epoch 195/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2406 - accuracy: 0.8997
# Epoch 196/200
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2402 - accuracy: 0.9006
# Epoch 197/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2277 - accuracy: 0.9020
# Epoch 198/200
# 316/316 [==============================] - 1s 3ms/step - loss: 0.2268 - accuracy: 0.9066
# Epoch 199/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2174 - accuracy: 0.9102
# Epoch 200/200
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2305 - accuracy: 0.9021
# 316/316 [==============================] - 0s 867us/step
# 6/6 [==============================] - 0s 1ms/step
#   0%|          | 0/100 [00:00<?, ?it/s]
# =================================================
# Training Classifer Portion of Type-A Model: Done!
# =================================================
# #---------------------------------------#
# Building Training Set (Regression): START
# #---------------------------------------#
# 100%|██████████| 100/100 [00:09<00:00, 10.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 562.32it/s]
# #-------------------------------------#
# Building Training Set (Regression): END
# #-------------------------------------#
# #-------------------------------------#
# Building Test Set (Predictions): START
# #-------------------------------------#
# #-----------------------------------#
# Building Test Set (Predictions): END
# #-----------------------------------#
# #-----------------------------#
# Building Barycenters Set: START
# #-----------------------------#
# #-----------------------------#
# Building Barycenters Set: END
# #-----------------------------#
#   0%|          | 36/10099 [00:00<00:28, 353.20it/s]
# Building Training Set Performance Metrics
# 100%|██████████| 10099/10099 [00:23<00:00, 426.21it/s]
#  15%|█▍        | 28/190 [00:00<00:00, 277.14it/s]
# Building Test Set Performance Metrics
# 100%|██████████| 190/190 [00:00<00:00, 332.14it/s]
# #----------------------#
# Training-Set Performance
# #----------------------#
#                W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min      0.469630  2.533043e-08         1.475371e-13                0.012050
# MAE   2176.150304  3.667541e+00         4.550599e+11               63.803318
# Max  73212.154615  8.859925e+02         4.353011e+15            17467.628899
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.052078
# MAE             94.578412
# Max          25637.008140
#
#
#
# #------------------#
# Test-Set Performance
# #------------------#
#                W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min      0.475551    0.587845         2.912933e+00                1.572590
# MAE   1996.868275    4.893398         8.080026e+07               32.599072
# Max  71117.131219   53.894239         5.358724e+09              530.086674
#
#      (E[X'^4]-E[X^4])^.25
# Min              1.696088
# MAE             45.730282
# Max            760.686098

# %% [markdown]
# # Visualization
# *From hereon out...do nothing and just let the backend sript run...the images and tables will load :).*

# %%
# Run Backend
# %run Universal_Processes_Trainer_Visuals.ipynb
exec(open('Universal_Processes_Trainer_Visuals.py').read())
# Out:
# Example Noises
# Example Paths
# Visualization of Training-Set Performance
# Visualizing Training Predictions vs. Ground-Truth (Training Set)
# No handles with labels found to put in legend.
# Visualization of Test-Set Performance
# Visualizing Training Predictions vs. Ground-Truth (Testing Set)
# No handles with labels found to put in legend.
# Visualizing Predictions Erros (Training Set)
# Visualizing Predictions Erros (Test Set)

# %% [markdown]
# ## Update User
# We empirically estimate the standard error and confidence intervals or the relevant error distributions using the method of this paper: [Bootstrap Methods for Standard Errors, Confidence Intervals, and Other Measures of Statistical Accuracy - by: B. Efron and R. Tibshirani ](https://www.jstor.org/stable/2245500?casa_token=w_8ZaRuo1qwAAAAA%3Ax5kzbYXzxGSWj-EZaC10XyOVADJyKQGXOVA9huJejP9Tt7fgMNhmPhj-C3WdgbB9AEZdqjT5q_azPmBLH6pDq61jzVFxV4XxqBuerQRBLaaOFKcyr0s&seq=1#metadata_info_tab_contents)

# %% [markdown]
# ### Training-Set Performance

# %%
Type_A_Prediction
# Out:
#                W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min      0.469630  2.533043e-08         1.475371e-13                0.012050
# MAE   2176.150304  3.667541e+00         4.550599e+11               63.803318
# Max  73212.154615  8.859925e+02         4.353011e+15            17467.628899
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.052078
# MAE             94.578412
# Max          25637.008140

# %% [markdown]
# #### Predictions

# %%
Type_A_Predictions_and_confidence.T
# Out:
#                            CL         Mean           CU
# W1_99_Train       2001.789890  2176.150304  2347.125403
# W1error_99_Train  1954.996244  2176.150304  2402.801158
# M_95_Train           7.391274     7.574860     7.748901
# M_99_Train           7.353564     7.574860     7.792020
# MC_95_Train          9.504012     9.842056    10.204727
# MC_99_Train          9.422391     9.842056    10.341706

# %% [markdown]
# ### Test-Set Performance

# %%
Type_A_Prediction_test
# Out:
#                W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min      0.475551    0.587845         2.912933e+00                1.572590
# MAE   1996.868275    4.893398         8.080026e+07               32.599072
# Max  71117.131219   53.894239         5.358724e+09              530.086674
#
#      (E[X'^4]-E[X^4])^.25
# Min              1.696088
# MAE             45.730282
# Max            760.686098

# %% [markdown]
# #### Predictions

# %%
Type_A_Predictions_and_confidence_test.T
# Out:
#                          CL         Mean           CU
# W1_99_Test       916.408902  1996.868275  3264.512440
# W1error_99_Test  674.231300  1996.868275  3852.917425
# M_95_Test          5.318388     6.631486     7.976870
# M_99_Test          5.014104     6.631486     8.590140
# MC_95_Test         1.627431     1.738088     1.852934
# MC_99_Test         1.586770     1.738088     1.911673

# %% [markdown]
# ### Model Complexity

# %%
Model_Complexity
# Out:
#                           N_Params  Training Time  N_Centers  N_Q
# Model_Complexity_metrics    101100     271.011453        100  100

# %% [markdown]
# ---

# %% [markdown]
# ---
# # Fin
# ---

# %% [markdown]
# ---
