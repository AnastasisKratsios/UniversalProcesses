# %% [markdown]
# ---
#
# # Generic Conditional Laws for Random-Fields - via:
#
# ## Universal $\mathcal{P}_1(\mathbb{R})$-Deep Neural Model (Type A)
#
# ---
#
# By: [Anastasis Kratsios](https://people.math.ethz.ch/~kratsioa/) - 2021.

# %% [markdown]
# ---

# %% [markdown]
# # Training Algorithm:
# ---
# ## 1) Generate Data:
# Generates the empirical measure $\sum_{n=1}^N \delta_{X_T(\omega_n)}$ of $X_T$ conditional on $X_0=x_0\in \mathbb{R}$ *($x_0$ and $T>0$ are user-provided)*.
#
# ## 2) Get "Sample Barycenters":
# Let $\{\mu_n\}_{n=1}^N\subset\mathcal{P}_1(\mathbb{R}^d)$.  Then, the *sample barycenter* is defined by:
# 1. $\mathcal{M}^{(0)}\triangleq \left\{\hat{\mu}_n\right\}_{n=1}^N$,
# 2. For $1\leq n\leq \mbox{N sample barycenters}$:
#     - $
# \mu^{\star}\in \underset{\tilde{\mu}\in \mathcal{M}^{(n)}}{\operatorname{argmin}}\, \sum_{n=1}^N \mathcal{W}_1\left(\mu^{\star},\mu_n\right),
# $
#     - $\mathcal{M}^{(n)}\triangleq \mathcal{M}^{(n-1)} - \{\mu^{\star}\},$
# *i.e., the closest generated measure form the random sample to all other elements of the random sample.*
#
# ---
# **Note:** *We simplify the computational burden of getting the correct classes by putting this right into this next loop.*
#
# ## 3) Train Deep Classifier:
# $\hat{f}\in \operatorname{argmin}_{f \in \mathcal{NN}_{d:N}^{\star}}
# \sum_{x \in \mathbb{X}}
# \,
# \mathbb{H}
# \left(
#     \operatorname{Softmax}_N\circ f(x)_n| I\left\{W_1(\hat{\mu}_n,\mu_x),\inf_{m\leq N} W_1(\hat{\mu}_m,\mu_x)\right\}
# \right);
# $
# where $\mathbb{H}$ is the categorical cross-entropy.
#
# ---
# ---
# ---
# ## Notes - Why the procedure is so computationally efficient?
# ---
#  - The sample barycenters do not require us to solve for any new Wasserstein-1 Barycenters; which is much more computationally costly,
#  - Our training procedure never back-propages through $\mathcal{W}_1$ since steps 2 and 3 are full-decoupled.  Therefore, training our deep classifier is (comparatively) cheap since it takes values in the standard $N$-simplex.
#
# ---

# %% [markdown]
# ## Meta-Parameters

# %% [markdown]
# ### Simulation

# %% [markdown]
# #### Ground Truth:
# *The build-in Options:*
# - rSDE
# - pfBM
# - 2lnflow

# %%
# Option 1:
groud_truth = "rSDE"
# Option 2:
# groud_truth = "2lnflow"
## Option 3:
# groud_truth = "pfBM"

# %% [markdown]
# #### Grid Hyperparameter(s)

# %%
## Monte-Carlo
N_Euler_Maruyama_Steps = 10*2
N_Monte_Carlo_Samples = 10**3
N_Monte_Carlo_Samples_Test = 10**3 # How many MC-samples to draw from test-set?

# End times for Time-Grid
T_end = 1
T_end_test = 1.1


## Grid
N_Grid_Finess = 10*2
Max_Grid = 0.5
x_0 = 1

# Number of Centers (\hat{\mu}_s)
N_Quantizers_to_parameterize = 200

# %% [markdown]
# This option sets $\delta$ in $B_{\mathbb{R}\times [0,\infty)}(\hat{x}_n,\delta)$; where $\hat{x}_n\in \nu_{\cdot}^{-1}[\hat{\mu}]$.  N_measures_per_center sets the number of samples to draw in this ball...by construction the training set is $\delta$-bounded and $\nu_{(x,t)}$, for any such $x$ is $\omega_{\nu_{\cdot}}(\delta)$-bounded in $\mathcal{P}_1(\mathbb{R})$.

# %%
# Hyper-parameters of Cover
delta = 0.1
N_measures_per_center = 10**2

# %% [markdown]
# **Note**: Setting *N_Quantizers_to_parameterize* prevents any barycenters and sub-sampling.

# %% [markdown]
# #### Mode: Code-Testin Parameter(s)
# - True: $\Rightarrow$ cross validation through grid of very mild parameters just to test hardward or software.
# - False: $\Rightarrow$ run CV-grid.

# %%
trial_run = False

# %% [markdown]
# ### Meta-parameters
# Ratio $\frac{\text{Testing Datasize}}{\text{Training Datasize}}$.

# %%
test_size_ratio = .25

# %% [markdown]
# ## Simulation from Rough SDE
# Simulate via Euler-M method from:
# $$
# X_T^x = x + \int_0^T \alpha(t,X_t^x)dt + \int_0^T((1-\eta)\beta(t,X_t^x)dW_t + \eta B_T^H.
# $$

# %% [markdown]
# ### Drift

# %%
def alpha(t,x):
    return .1

# %% [markdown]
# ### Volatility

# %%
def beta(t,x):
    return .01

# %% [markdown]
# ### Roughness Meta-parameters
#  - Roughness is $H$,
#  - Ratio_fBM_to_typical_vol is $\eta$.

# %%
Rougness = 0.01 # Hurst Parameter
Ratio_fBM_to_typical_vol = 0.5# $\eta$ in equation above.

# %% [markdown]
# ## Simulation from Measure-Valued $2$-Parameter Log-Gaussian Flow
# $$
# X_{t,x} \sim \log\text{-}\mathcal{N}\left(\alpha(t,x),\beta(t,x)\right).
# $$

# %% [markdown]
# **Note:** *$\alpha$ and $\beta$ are specified below in the SDE Example*.

# %%
# Run Backend
# %run Universal_Processes_Trainer_BACKEND.ipynb
exec(open('Universal_Processes_Trainer_BACKEND.py').read())
# Out:
# Using TensorFlow backend.
#   0%|          | 0/14 [00:00<?, ?it/s]
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# Building Training + Testing Set - rough-SDE Ground-Truth
# /scratch/users/kratsioa/.local/lib/python3.7/site-packages/fbm/fbm.py:172: UserWarning: Combination of increments n and Hurst value H invalid for Davies-Harte method. Reverting to Hosking method. Occurs when n is small and Hurst is close to 1.
#   "Combination of increments n and Hurst value H "
# 100%|██████████| 14/14 [00:10<00:00,  1.36it/s]
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# ==========================================
# Training Classifer Portion of Type-A Model
# ==========================================
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=4)]: Done  16 out of  20 | elapsed:   29.8s remaining:    7.5s
# [Parallel(n_jobs=4)]: Done  20 out of  20 | elapsed:   36.7s finished
# Epoch 1/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6246 - accuracy: 0.0714
# Epoch 2/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5777 - accuracy: 0.1190
# Epoch 3/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5116 - accuracy: 0.1286
# Epoch 4/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4302 - accuracy: 0.1619
# Epoch 5/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3264 - accuracy: 0.2143
# Epoch 6/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2103 - accuracy: 0.2190
# Epoch 7/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0851 - accuracy: 0.2238
# Epoch 8/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9561 - accuracy: 0.2095
# Epoch 9/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8252 - accuracy: 0.2905
# Epoch 10/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7158 - accuracy: 0.3095
# Epoch 11/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6156 - accuracy: 0.3952
# Epoch 12/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5012 - accuracy: 0.4429
# Epoch 13/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4250 - accuracy: 0.4952
# Epoch 14/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3407 - accuracy: 0.6095
# Epoch 15/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2478 - accuracy: 0.6190
# Epoch 16/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2107 - accuracy: 0.5762
# Epoch 17/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1291 - accuracy: 0.6381
# Epoch 18/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1068 - accuracy: 0.6238
# Epoch 19/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0048 - accuracy: 0.7238
# Epoch 20/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9759 - accuracy: 0.7190
# Epoch 21/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9336 - accuracy: 0.7238
# Epoch 22/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8690 - accuracy: 0.7762
# Epoch 23/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8213 - accuracy: 0.8095
# Epoch 24/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8075 - accuracy: 0.7810
# Epoch 25/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7404 - accuracy: 0.8952
# Epoch 26/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7062 - accuracy: 0.8476
# Epoch 27/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6777 - accuracy: 0.8762
# Epoch 28/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6234 - accuracy: 0.8714
# Epoch 29/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6265 - accuracy: 0.8762
# Epoch 30/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6037 - accuracy: 0.8333
# Epoch 31/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5947 - accuracy: 0.8571
# Epoch 32/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5344 - accuracy: 0.9238
# Epoch 33/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5002 - accuracy: 0.9048
# Epoch 34/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.9381
# Epoch 35/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.9429
# Epoch 36/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.9000
# Epoch 37/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4233 - accuracy: 0.9571
# Epoch 38/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.9667
# Epoch 39/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3607 - accuracy: 0.9762
# Epoch 40/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.9571
# Epoch 41/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3308 - accuracy: 0.9810
# Epoch 42/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.9429
# Epoch 43/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.9190
# Epoch 44/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3666 - accuracy: 0.8571
# Epoch 45/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2977 - accuracy: 0.9286
# Epoch 46/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 1.0000
# Epoch 47/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2398 - accuracy: 0.9810
# Epoch 48/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2524 - accuracy: 0.9667
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2151 - accuracy: 1.0000
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2042 - accuracy: 1.0000
# Epoch 51/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1853 - accuracy: 1.0000
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 1.0000
# Epoch 53/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1767 - accuracy: 1.0000
# Epoch 54/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1851 - accuracy: 0.9952
# Epoch 55/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1592 - accuracy: 1.0000
# Epoch 56/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1607 - accuracy: 1.0000
# Epoch 57/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 1.0000
# Epoch 58/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1332 - accuracy: 1.0000
# Epoch 59/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1306 - accuracy: 1.0000
# Epoch 60/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 1.0000
# Epoch 61/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 1.0000
# Epoch 62/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 1.0000
# Epoch 63/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1017 - accuracy: 1.0000
# Epoch 64/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 1.0000
# Epoch 65/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 1.0000
# Epoch 66/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0928 - accuracy: 1.0000
# Epoch 67/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 68/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 1.0000
# Epoch 69/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 1.0000
# Epoch 70/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 1.0000
# Epoch 71/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 1.0000
# Epoch 72/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 73/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 74/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 1.0000
# Epoch 75/200
# 7/7 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 77/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 78/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 79/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 80/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 1.0000
# Epoch 81/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 82/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 83/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 84/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 1.0000
# Epoch 85/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 86/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 87/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 88/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 89/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 90/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 91/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 92/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 93/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 94/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 95/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 96/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 97/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 98/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 99/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 100/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 101/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 102/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 103/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 104/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 105/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 106/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 107/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 108/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 109/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 110/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 111/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 112/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 113/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 114/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 115/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 116/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 117/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 118/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 119/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 120/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 121/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 122/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 123/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 124/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 125/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 126/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 127/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 128/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 129/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 130/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 131/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 132/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 133/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 134/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 135/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 136/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 137/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 138/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 139/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 140/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 141/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 142/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 143/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 144/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 145/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 146/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 147/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 148/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 149/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 150/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 151/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 152/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 153/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 154/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 155/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 156/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 157/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 158/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 159/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 160/200
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 161/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 162/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 163/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 165/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 166/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 167/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 168/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 169/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 170/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 171/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 172/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 173/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 174/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 175/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 176/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 177/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 178/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 179/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 180/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 181/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 182/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 183/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 184/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 185/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 186/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 187/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 188/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 189/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 190/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 191/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 192/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 193/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 194/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 195/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 196/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 197/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 198/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 199/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 200/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# 7/7 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
#   0%|          | 0/14 [00:00<?, ?it/s]
# =================================================
# Training Classifer Portion of Type-A Model: Done!
# =================================================
# #---------------------------------------#
# Building Training Set (Regression): START
# #---------------------------------------#
# 100%|██████████| 14/14 [00:00<00:00, 184.35it/s]
# 100%|██████████| 14/14 [00:00<00:00, 578.86it/s]
#   0%|          | 0/209 [00:00<?, ?it/s]
# #-------------------------------------#
# Building Training Set (Regression): END
# #-------------------------------------#
# #-------------------------------------#
# Building Test Set (Predictions): START
# #-------------------------------------#
# #-----------------------------------#
# Building Test Set (Predictions): END
# #-----------------------------------#
# #-----------------------------#
# Building Barycenters Set: START
# #-----------------------------#
# #-----------------------------#
# Building Barycenters Set: END
# #-----------------------------#
# Building Training Set Performance Metrics
# 100%|██████████| 209/209 [00:00<00:00, 322.94it/s]
# 100%|██████████| 70/70 [00:00<00:00, 352.36it/s]
# Building Test Set Performance Metrics
# #----------------------#
# Training-Set Performance
# #----------------------#
#             W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min 9.6876E-05  5.0106E-06           1.8625E-10              2.6458E-02
# MAE 4.4536E-01  4.8175E-03           4.8571E-03              4.4824E-01
# Max 7.0495E+00  1.7130E-02           2.9065E-02              8.0870E-01
#
#      (E[X'^4]-E[X^4])^.25
# Min            6.6350E-02
# MAE            6.3186E-01
# Max            1.1120E+00
#
#
#
# #------------------#
# Test-Set Performance
# #------------------#
#             W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min 9.6876E-05  5.0106E-06           1.8625E-10              2.6458E-02
# MAE 5.2688E-02  1.6176E-03           8.7641E-05              2.1230E-01
# Max 2.1088E-01  6.9539E-03           5.1682E-04              4.1632E-01
#
#      (E[X'^4]-E[X^4])^.25
# Min            6.6350E-02
# MAE            3.5242E-01
# Max            6.6827E-01

# %% [markdown]
# # Visualization
# *From hereon out...do nothing and just let the backend sript run...the images and tables will load :).*

# %%
# Run Backend
# %run Universal_Processes_Trainer_Visuals.ipynb
exec(open('Universal_Processes_Trainer_Visuals.py').read())
# Out:
# Example Noises
# Example Paths
# Visualization of Training-Set Performance
# No handles with labels found to put in legend.
# Visualizing Training Predictions vs. Ground-Truth (Training Set)
# Visualization of Test-Set Performance
# Visualizing Training Predictions vs. Ground-Truth (Testing Set)
# No handles with labels found to put in legend.
# Visualizing Predictions Erros (Training Set)
# Visualizing Predictions Erros (Test Set)

# %% [markdown]
# ## Update User
# We empirically estimate the standard error and confidence intervals or the relevant error distributions using the method of this paper: [Bootstrap Methods for Standard Errors, Confidence Intervals, and Other Measures of Statistical Accuracy - by: B. Efron and R. Tibshirani ](https://www.jstor.org/stable/2245500?casa_token=w_8ZaRuo1qwAAAAA%3Ax5kzbYXzxGSWj-EZaC10XyOVADJyKQGXOVA9huJejP9Tt7fgMNhmPhj-C3WdgbB9AEZdqjT5q_azPmBLH6pDq61jzVFxV4XxqBuerQRBLaaOFKcyr0s&seq=1#metadata_info_tab_contents)

# %% [markdown]
# ### Training-Set Performance

# %%
Type_A_Prediction
# Out:
#             W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min 9.6876E-05  5.0106E-06           1.8625E-10              2.6458E-02
# MAE 4.4536E-01  4.8175E-03           4.8571E-03              4.4824E-01
# Max 7.0495E+00  1.7130E-02           2.9065E-02              8.0870E-01
#
#      (E[X'^4]-E[X^4])^.25
# Min            6.6350E-02
# MAE            6.3186E-01
# Max            1.1120E+00

# %% [markdown]
# #### Predictions

# %%
Type_A_Predictions_and_confidence.T
# Out:
#                           CL       Mean         CU
# W1_99_Train      -5.7088E-03 1.2115E-01 2.2590E-01
# W1error_99_Train -6.4114E-02 1.2115E-01 2.5980E-01
# M_95_Train        9.2465E-01 9.6260E-01 1.0016E+00
# M_99_Train        9.1065E-01 9.6260E-01 1.0152E+00
# MC_95_Train       9.2909E-01 9.6483E-01 1.0056E+00
# MC_99_Train       9.1320E-01 9.6483E-01 1.0195E+00

# %% [markdown]
# ### Test-Set Performance

# %%
Type_A_Prediction_test
# Out:
#             W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min 9.6876E-05  5.0106E-06           1.8625E-10              2.6458E-02
# MAE 5.2688E-02  1.6176E-03           8.7641E-05              2.1230E-01
# Max 2.1088E-01  6.9539E-03           5.1682E-04              4.1632E-01
#
#      (E[X'^4]-E[X^4])^.25
# Min            6.6350E-02
# MAE            3.5242E-01
# Max            6.6827E-01

# %% [markdown]
# #### Predictions

# %%
Type_A_Predictions_and_confidence_test.T
# Out:
#                         CL       Mean         CU
# W1_99_Test      4.0860E-02 5.2688E-02 6.3671E-02
# W1error_99_Test 3.8092E-02 5.2688E-02 7.0226E-02
# M_95_Test       8.9748E-01 9.6482E-01 1.0291E+00
# M_99_Test       8.8218E-01 9.6482E-01 1.0556E+00
# MC_95_Test      9.0083E-01 9.6555E-01 1.0334E+00
# MC_99_Test      8.7410E-01 9.6555E-01 1.0562E+00

# %% [markdown]
# ### Model Complexity

# %%
Model_Complexity
# Out:
#                           N_Centers   N_Q  N_Params  Training Time  \
# Model_Complexity_metrics         14  1000     83814     5.1841E+01
#
#                           T_Test/T_Test-MC  Time Test  Time EM-MC
# Model_Complexity_metrics        4.3162E-03 4.4398E-02  1.0286E+01

# %% [markdown]
# ---

# %% [markdown]
# ---
# # Fin
# ---

# %% [markdown]
# ---
