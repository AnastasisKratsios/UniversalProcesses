# %% [markdown]
# ---
#
# # Generic Conditional Laws for Random-Fields - via:
#
# ## Universal $\mathcal{P}_1(\mathbb{R})$-Deep Neural Model (Type A)
#
# ---
#
# By: [Anastasis Kratsios](https://people.math.ethz.ch/~kratsioa/) - 2021.

# %% [markdown]
# ---

# %% [markdown]
# # Training Algorithm:
# ---
# ## 1) Generate Data:
# Generates the empirical measure $\sum_{n=1}^N \delta_{X_T(\omega_n)}$ of $X_T$ conditional on $X_0=x_0\in \mathbb{R}$ *($x_0$ and $T>0$ are user-provided)*.
#
# ## 2) Get "Sample Barycenters":
# Let $\{\mu_n\}_{n=1}^N\subset\mathcal{P}_1(\mathbb{R}^d)$.  Then, the *sample barycenter* is defined by:
# 1. $\mathcal{M}^{(0)}\triangleq \left\{\hat{\mu}_n\right\}_{n=1}^N$,
# 2. For $1\leq n\leq \mbox{N sample barycenters}$:
#     - $
# \mu^{\star}\in \underset{\tilde{\mu}\in \mathcal{M}^{(n)}}{\operatorname{argmin}}\, \sum_{n=1}^N \mathcal{W}_1\left(\mu^{\star},\mu_n\right),
# $
#     - $\mathcal{M}^{(n)}\triangleq \mathcal{M}^{(n-1)} - \{\mu^{\star}\},$
# *i.e., the closest generated measure form the random sample to all other elements of the random sample.*
#
# ---
# **Note:** *We simplify the computational burden of getting the correct classes by putting this right into this next loop.*
#
# ## 3) Train Deep Classifier:
# $\hat{f}\in \operatorname{argmin}_{f \in \mathcal{NN}_{d:N}^{\star}}
# \sum_{x \in \mathbb{X}}
# \,
# \mathbb{H}
# \left(
#     \operatorname{Softmax}_N\circ f(x)_n| I\left\{W_1(\hat{\mu}_n,\mu_x),\inf_{m\leq N} W_1(\hat{\mu}_m,\mu_x)\right\}
# \right);
# $
# where $\mathbb{H}$ is the categorical cross-entropy.
#
# ---
# ---
# ---
# ## Notes - Why the procedure is so computationally efficient?
# ---
#  - The sample barycenters do not require us to solve for any new Wasserstein-1 Barycenters; which is much more computationally costly,
#  - Our training procedure never back-propages through $\mathcal{W}_1$ since steps 2 and 3 are full-decoupled.  Therefore, training our deep classifier is (comparatively) cheap since it takes values in the standard $N$-simplex.
#
# ---

# %% [markdown]
# ## Meta-Parameters

# %% [markdown]
# ### Simulation

# %% [markdown]
# #### Ground Truth:
# *The build-in Options:*
# - rSDE
# - pfBM
# - 2lnflow

# %%
# Option 1:
groud_truth = "rSDE"
# Option 2:
# groud_truth = "2lnflow"
## Option 3:
# groud_truth = "pfBM"

# %% [markdown]
# #### Grid Hyperparameter(s)

# %%
## Monte-Carlo
N_Euler_Maruyama_Steps = 100
N_Monte_Carlo_Samples = 10**3
N_Monte_Carlo_Samples_Test = 10**4 # How many MC-samples to draw from test-set?

# End times for Time-Grid
T_end = 1
T_end_test = 1.1


## Grid
N_Grid_Finess = 100
Max_Grid = 0.5
x_0 = 1

# Number of Centers (\hat{\mu}_s)
N_Quantizers_to_parameterize = 10

# %% [markdown]
# This option sets $\delta$ in $B_{\mathbb{R}\times [0,\infty)}(\hat{x}_n,\delta)$; where $\hat{x}_n\in \nu_{\cdot}^{-1}[\hat{\mu}]$.  N_measures_per_center sets the number of samples to draw in this ball...by construction the training set is $\delta$-bounded and $\nu_{(x,t)}$, for any such $x$ is $\omega_{\nu_{\cdot}}(\delta)$-bounded in $\mathcal{P}_1(\mathbb{R})$.

# %%
# Hyper-parameters of Cover
delta = 0.1
N_measures_per_center = 100

# %% [markdown]
# **Note**: Setting *N_Quantizers_to_parameterize* prevents any barycenters and sub-sampling.

# %% [markdown]
# #### Mode: Code-Testin Parameter(s)
# - True: $\Rightarrow$ cross validation through grid of very mild parameters just to test hardward or software.
# - False: $\Rightarrow$ run CV-grid.

# %%
trial_run = True

# %% [markdown]
# ### Meta-parameters
# Ratio $\frac{\text{Testing Datasize}}{\text{Training Datasize}}$.

# %%
test_size_ratio = .25

# %% [markdown]
# ## Simulation from Rough SDE
# Simulate via Euler-M method from:
# $$
# X_T^x = x + \int_0^T \alpha(s,X_s^x)ds + \int_0^T((1-\eta)\beta(s,X_s^s)+\eta\sigma_s^H)dW_s.
# $$

# %% [markdown]
# ### Drift

# %%
def alpha(t,x):
    return np.exp(t)*np.cos(x)-x

# %% [markdown]
# ### Volatility

# %%
def beta(t,x):
    return 0.5*np.sin(np.abs(t))*np.exp(-x)

# %% [markdown]
# ### Roughness Meta-parameters
#  - Roughness is $H$,
#  - Ratio_fBM_to_typical_vol is $\eta$.

# %%
Rougness = 0.9 # Hurst Parameter
Ratio_fBM_to_typical_vol = 0.5 # $\eta$ in equation above.

# %% [markdown]
# ## Simulation from Measure-Valued $2$-Parameter Log-Gaussian Flow
# $$
# X_{t,x} \sim \log\text{-}\mathcal{N}\left(\alpha(t,x),\beta(t,x)\right).
# $$

# %% [markdown]
# **Note:** *$\alpha$ and $\beta$ are specified below in the SDE Example*.

# %%
# Run Backend
# %run Universal_Processes_Trainer_BACKEND.ipynb
exec(open('Universal_Processes_Trainer_BACKEND.py').read())
# Out:
# Using TensorFlow backend.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# Building Training + Testing Set - rough-SDE Ground-Truth
# 100%|██████████| 3/3 [00:11<00:00,  3.84s/it]
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# ==========================================
# Training Classifer Portion of Type-A Model
# ==========================================
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    7.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    7.3s finished
# Epoch 1/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0413 - accuracy: 0.5644
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8832 - accuracy: 0.6667
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6982 - accuracy: 0.6933
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4996 - accuracy: 0.8178
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3527 - accuracy: 0.8578
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.9111
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1633 - accuracy: 0.9422
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 1.0000
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 1.0000
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.8886e-04 - accuracy: 1.0000
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9174e-04 - accuracy: 1.0000
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.9536e-04 - accuracy: 1.0000
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.9548e-04 - accuracy: 1.0000
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.1544e-04 - accuracy: 1.0000
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.5380e-04 - accuracy: 1.0000
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.0486e-04 - accuracy: 1.0000
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.5725e-04 - accuracy: 1.0000
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0790e-04 - accuracy: 1.0000
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7002e-04 - accuracy: 1.0000
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4567e-04 - accuracy: 1.0000
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.2307e-04 - accuracy: 1.0000
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0088e-04 - accuracy: 1.0000
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7984e-04 - accuracy: 1.0000
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.6102e-04 - accuracy: 1.0000
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4247e-04 - accuracy: 1.0000
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2756e-04 - accuracy: 1.0000
# Epoch 39/200
# 8/8 [==============================] - 0s 1ms/step - loss: 2.1636e-04 - accuracy: 1.0000
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0592e-04 - accuracy: 1.0000
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9166e-04 - accuracy: 1.0000
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8057e-04 - accuracy: 1.0000
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7064e-04 - accuracy: 1.0000
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5915e-04 - accuracy: 1.0000
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5549e-04 - accuracy: 1.0000
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4786e-04 - accuracy: 1.0000
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3976e-04 - accuracy: 1.0000
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3226e-04 - accuracy: 1.0000
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2596e-04 - accuracy: 1.0000
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2025e-04 - accuracy: 1.0000
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1546e-04 - accuracy: 1.0000
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1091e-04 - accuracy: 1.0000
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0713e-04 - accuracy: 1.0000
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0252e-04 - accuracy: 1.0000
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.8094e-05 - accuracy: 1.0000
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.3683e-05 - accuracy: 1.0000
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.0325e-05 - accuracy: 1.0000
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7126e-05 - accuracy: 1.0000
# Epoch 59/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3871e-05 - accuracy: 1.0000
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1271e-05 - accuracy: 1.0000
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.8836e-05 - accuracy: 1.0000
# Epoch 62/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.5730e-05 - accuracy: 1.0000
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.2625e-05 - accuracy: 1.0000
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0190e-05 - accuracy: 1.0000
# Epoch 65/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.7794e-05 - accuracy: 1.0000
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.5549e-05 - accuracy: 1.0000
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.3650e-05 - accuracy: 1.0000
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.0836e-05 - accuracy: 1.0000
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.8479e-05 - accuracy: 1.0000
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.6611e-05 - accuracy: 1.0000
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4786e-05 - accuracy: 1.0000
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.3037e-05 - accuracy: 1.0000
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.1044e-05 - accuracy: 1.0000
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.9304e-05 - accuracy: 1.0000
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.7299e-05 - accuracy: 1.0000
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.5679e-05 - accuracy: 1.0000
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4238e-05 - accuracy: 1.0000
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2929e-05 - accuracy: 1.0000
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.1685e-05 - accuracy: 1.0000
# Epoch 80/200
# 8/8 [==============================] - 0s 1ms/step - loss: 4.0233e-05 - accuracy: 1.0000
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9179e-05 - accuracy: 1.0000
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8036e-05 - accuracy: 1.0000
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6966e-05 - accuracy: 1.0000
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6005e-05 - accuracy: 1.0000
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5174e-05 - accuracy: 1.0000
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4333e-05 - accuracy: 1.0000
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3491e-05 - accuracy: 1.0000
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.2731e-05 - accuracy: 1.0000
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.1786e-05 - accuracy: 1.0000
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.1015e-05 - accuracy: 1.0000
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0116e-05 - accuracy: 1.0000
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9242e-05 - accuracy: 1.0000
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8372e-05 - accuracy: 1.0000
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7670e-05 - accuracy: 1.0000
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7048e-05 - accuracy: 1.0000
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.6484e-05 - accuracy: 1.0000
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5897e-05 - accuracy: 1.0000
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5206e-05 - accuracy: 1.0000
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4555e-05 - accuracy: 1.0000
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3987e-05 - accuracy: 1.0000
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3472e-05 - accuracy: 1.0000
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.3029e-05 - accuracy: 1.0000
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2544e-05 - accuracy: 1.0000
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.2082e-05 - accuracy: 1.0000
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1719e-05 - accuracy: 1.0000
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1314e-05 - accuracy: 1.0000
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0888e-05 - accuracy: 1.0000
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0402e-05 - accuracy: 1.0000
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9951e-05 - accuracy: 1.0000
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9592e-05 - accuracy: 1.0000
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9199e-05 - accuracy: 1.0000
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8853e-05 - accuracy: 1.0000
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8451e-05 - accuracy: 1.0000
# Epoch 114/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8142e-05 - accuracy: 1.0000
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7870e-05 - accuracy: 1.0000
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7373e-05 - accuracy: 1.0000
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6985e-05 - accuracy: 1.0000
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6673e-05 - accuracy: 1.0000
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6388e-05 - accuracy: 1.0000
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6103e-05 - accuracy: 1.0000
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5833e-05 - accuracy: 1.0000
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5567e-05 - accuracy: 1.0000
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5231e-05 - accuracy: 1.0000
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4991e-05 - accuracy: 1.0000
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4729e-05 - accuracy: 1.0000
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4445e-05 - accuracy: 1.0000
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4199e-05 - accuracy: 1.0000
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3983e-05 - accuracy: 1.0000
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3754e-05 - accuracy: 1.0000
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3526e-05 - accuracy: 1.0000
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3288e-05 - accuracy: 1.0000
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3066e-05 - accuracy: 1.0000
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2866e-05 - accuracy: 1.0000
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2673e-05 - accuracy: 1.0000
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2478e-05 - accuracy: 1.0000
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2280e-05 - accuracy: 1.0000
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2081e-05 - accuracy: 1.0000
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1913e-05 - accuracy: 1.0000
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1736e-05 - accuracy: 1.0000
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1557e-05 - accuracy: 1.0000
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1398e-05 - accuracy: 1.0000
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1189e-05 - accuracy: 1.0000
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1004e-05 - accuracy: 1.0000
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0824e-05 - accuracy: 1.0000
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0649e-05 - accuracy: 1.0000
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0493e-05 - accuracy: 1.0000
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0350e-05 - accuracy: 1.0000
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0165e-05 - accuracy: 1.0000
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0011e-05 - accuracy: 1.0000
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.8704e-06 - accuracy: 1.0000
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7326e-06 - accuracy: 1.0000
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.5997e-06 - accuracy: 1.0000
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.4577e-06 - accuracy: 1.0000
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.3337e-06 - accuracy: 1.0000
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.2007e-06 - accuracy: 1.0000
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 9.0730e-06 - accuracy: 1.0000
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9464e-06 - accuracy: 1.0000
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7965e-06 - accuracy: 1.0000
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6571e-06 - accuracy: 1.0000
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5130e-06 - accuracy: 1.0000
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3943e-06 - accuracy: 1.0000
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2773e-06 - accuracy: 1.0000
# Epoch 163/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1777e-06 - accuracy: 1.0000
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.0738e-06 - accuracy: 1.0000
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.9705e-06 - accuracy: 1.0000
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.8640e-06 - accuracy: 1.0000
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.7655e-06 - accuracy: 1.0000
# Epoch 168/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.6664e-06 - accuracy: 1.0000
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.5678e-06 - accuracy: 1.0000
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.4735e-06 - accuracy: 1.0000
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.3745e-06 - accuracy: 1.0000
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.2685e-06 - accuracy: 1.0000
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.1800e-06 - accuracy: 1.0000
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0794e-06 - accuracy: 1.0000
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.9941e-06 - accuracy: 1.0000
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.8674e-06 - accuracy: 1.0000
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.7604e-06 - accuracy: 1.0000
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.6820e-06 - accuracy: 1.0000
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.6052e-06 - accuracy: 1.0000
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.5199e-06 - accuracy: 1.0000
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.4404e-06 - accuracy: 1.0000
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.3631e-06 - accuracy: 1.0000
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.2815e-06 - accuracy: 1.0000
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.2121e-06 - accuracy: 1.0000
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.1294e-06 - accuracy: 1.0000
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.0706e-06 - accuracy: 1.0000
# Epoch 187/200
# 8/8 [==============================] - ETA: 0s - loss: 5.1073e-06 - accuracy: 1.00 - 0s 2ms/step - loss: 6.0229e-06 - accuracy: 1.0000
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.9668e-06 - accuracy: 1.0000
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.8799e-06 - accuracy: 1.0000
# Epoch 190/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.7760e-06 - accuracy: 1.0000
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.6589e-06 - accuracy: 1.0000
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.5625e-06 - accuracy: 1.0000
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4857e-06 - accuracy: 1.0000
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4179e-06 - accuracy: 1.0000
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.3543e-06 - accuracy: 1.0000
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2918e-06 - accuracy: 1.0000
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2393e-06 - accuracy: 1.0000
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.1795e-06 - accuracy: 1.0000
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.1228e-06 - accuracy: 1.0000
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.0645e-06 - accuracy: 1.0000
# 8/8 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
#   0%|          | 0/3 [00:00<?, ?it/s]
# =================================================
# Training Classifer Portion of Type-A Model: Done!
# =================================================
# #---------------------------------------#
# Building Training Set (Regression): START
# #---------------------------------------#
# 100%|██████████| 3/3 [00:00<00:00, 166.76it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# #-------------------------------------#
# Building Training Set (Regression): END
# #-------------------------------------#
# #-------------------------------------#
# Building Test Set (Predictions): START
# #-------------------------------------#
# 100%|██████████| 3/3 [00:00<00:00, 1050.15it/s]
#   0%|          | 0/224 [00:00<?, ?it/s]
# #-----------------------------------#
# Building Test Set (Predictions): END
# #-----------------------------------#
# #-----------------------------#
# Building Barycenters Set: START
# #-----------------------------#
# #-----------------------------#
# Building Barycenters Set: END
# #-----------------------------#
# Building Training Set Performance Metrics
# 100%|██████████| 224/224 [00:00<00:00, 810.30it/s]
# 100%|██████████| 75/75 [00:00<00:00, 833.91it/s]
# Building Test Set Performance Metrics
# #----------------------#
# Training-Set Performance
# #----------------------#
#                W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  2.050107e-07  7.043840e-07         9.294664e-13                0.009973
# MAE  2.200112e-03  1.523895e-02         1.724310e-03                0.286881
# Max  1.673954e-02  5.097543e-02         1.347893e-02                0.583201
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.030979
# MAE              0.396906
# Max              0.740897
#
#
#
# #------------------#
# Test-Set Performance
# #------------------#
#                W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  1.233021e-07  7.043840e-07         9.294664e-13                0.009973
# MAE  1.883181e-04  5.133414e-03         2.106936e-04                0.198621
# Max  1.585399e-03  1.784840e-02         1.704864e-03                0.415324
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.030979
# MAE              0.300887
# Max              0.576545

# %% [markdown]
# # Visualization
# *From hereon out...do nothing and just let the backend sript run...the images and tables will load :).*

# %%
# Run Backend
# %run Universal_Processes_Trainer_Visuals.ipynb
exec(open('Universal_Processes_Trainer_Visuals.py').read())
# Out:
# Example Noises
# Example Paths
# Visualization of Training-Set Performance
# No handles with labels found to put in legend.
# Visualizing Training Predictions vs. Ground-Truth (Training Set)
# Visualization of Test-Set Performance
# Visualizing Training Predictions vs. Ground-Truth (Testing Set)
# No handles with labels found to put in legend.
# Visualizing Predictions Erros (Training Set)
# Visualizing Predictions Erros (Test Set)

# %% [markdown]
# ## Update User
# We empirically estimate the standard error and confidence intervals or the relevant error distributions using the method of this paper: [Bootstrap Methods for Standard Errors, Confidence Intervals, and Other Measures of Statistical Accuracy - by: B. Efron and R. Tibshirani ](https://www.jstor.org/stable/2245500?casa_token=w_8ZaRuo1qwAAAAA%3Ax5kzbYXzxGSWj-EZaC10XyOVADJyKQGXOVA9huJejP9Tt7fgMNhmPhj-C3WdgbB9AEZdqjT5q_azPmBLH6pDq61jzVFxV4XxqBuerQRBLaaOFKcyr0s&seq=1#metadata_info_tab_contents)

# %% [markdown]
# ### Training-Set Performance

# %%
Type_A_Prediction
# Out:
#                W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  2.050107e-07  7.043840e-07         9.294664e-13                0.009973
# MAE  2.200112e-03  1.523895e-02         1.724310e-03                0.286881
# Max  1.673954e-02  5.097543e-02         1.347893e-02                0.583201
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.030979
# MAE              0.396906
# Max              0.740897

# %% [markdown]
# #### Predictions

# %%
Type_A_Predictions_and_confidence.T
# Out:
#                         CL      Mean        CU
# W1_99_Train       0.001823  0.002200  0.002619
# W1error_99_Train  0.001673  0.002200  0.002750
# M_95_Train        0.794526  0.831662  0.868798
# M_99_Train        0.791555  0.831662  0.882166
# MC_95_Train       0.792633  0.825982  0.857916
# MC_99_Train       0.786161  0.825982  0.867944

# %% [markdown]
# ### Test-Set Performance

# %%
Type_A_Prediction_test
# Out:
#                W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  1.233021e-07  7.043840e-07         9.294664e-13                0.009973
# MAE  1.883181e-04  5.133414e-03         2.106936e-04                0.198621
# Max  1.585399e-03  1.784840e-02         1.704864e-03                0.415324
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.030979
# MAE              0.300887
# Max              0.576545

# %% [markdown]
# #### Predictions

# %%
Type_A_Predictions_and_confidence_test.T
# Out:
#                        CL      Mean        CU
# W1_99_Test       0.000126  0.000188  0.000265
# W1error_99_Test  0.000102  0.000188  0.000300
# M_95_Test        0.775467  0.833148  0.890825
# M_99_Test        0.762158  0.833148  0.908573
# MC_95_Test       0.770408  0.831037  0.895621
# MC_99_Test       0.760878  0.831037  0.908142

# %% [markdown]
# ### Model Complexity

# %%
Model_Complexity
# Out:
#                           N_Params  Training Time  N_Centers   N_Q
# Model_Complexity_metrics     81603      24.081006          3  1000

# %% [markdown]
# ---

# %% [markdown]
# ---
# # Fin
# ---

# %% [markdown]
# ---
