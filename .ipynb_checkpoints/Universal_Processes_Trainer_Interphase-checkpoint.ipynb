# %% [markdown]
# ---
#
# # Generic Conditional Laws for Random-Fields - via:
#
# ## Universal $\mathcal{P}_1(\mathbb{R})$-Deep Neural Model (Type A)
#
# ---
#
# By: [Anastasis Kratsios](https://people.math.ethz.ch/~kratsioa/) - 2021.

# %% [markdown]
# ---

# %% [markdown]
# # Training Algorithm:
# ---
# ## 1) Generate Data:
# Generates the empirical measure $\sum_{n=1}^N \delta_{X_T(\omega_n)}$ of $X_T$ conditional on $X_0=x_0\in \mathbb{R}$ *($x_0$ and $T>0$ are user-provided)*.
#
# ## 2) Get "Sample Barycenters":
# Let $\{\mu_n\}_{n=1}^N\subset\mathcal{P}_1(\mathbb{R}^d)$.  Then, the *sample barycenter* is defined by:
# 1. $\mathcal{M}^{(0)}\triangleq \left\{\hat{\mu}_n\right\}_{n=1}^N$,
# 2. For $1\leq n\leq \mbox{N sample barycenters}$:
#     - $
# \mu^{\star}\in \underset{\tilde{\mu}\in \mathcal{M}^{(n)}}{\operatorname{argmin}}\, \sum_{n=1}^N \mathcal{W}_1\left(\mu^{\star},\mu_n\right),
# $
#     - $\mathcal{M}^{(n)}\triangleq \mathcal{M}^{(n-1)} - \{\mu^{\star}\},$
# *i.e., the closest generated measure form the random sample to all other elements of the random sample.*
#
# ---
# **Note:** *We simplify the computational burden of getting the correct classes by putting this right into this next loop.*
#
# ## 3) Train Deep Classifier:
# $\hat{f}\in \operatorname{argmin}_{f \in \mathcal{NN}_{d:N}^{\star}}
# \sum_{x \in \mathbb{X}}
# \,
# \mathbb{H}
# \left(
#     \operatorname{Softmax}_N\circ f(x)_n| I\left\{W_1(\hat{\mu}_n,\mu_x),\inf_{m\leq N} W_1(\hat{\mu}_m,\mu_x)\right\}
# \right);
# $
# where $\mathbb{H}$ is the categorical cross-entropy.
#
# ---
# ---
# ---
# ## Notes - Why the procedure is so computationally efficient?
# ---
#  - The sample barycenters do not require us to solve for any new Wasserstein-1 Barycenters; which is much more computationally costly,
#  - Our training procedure never back-propages through $\mathcal{W}_1$ since steps 2 and 3 are full-decoupled.  Therefore, training our deep classifier is (comparatively) cheap since it takes values in the standard $N$-simplex.
#
# ---

# %% [markdown]
# ## Meta-Parameters

# %% [markdown]
# ### Simulation

# %% [markdown]
# #### Ground Truth:
# *The build-in Options:*
# - rSDE
# - pfBM
# - 2lnflow

# %%
# Option 1:
groud_truth = "rSDE"
# Option 2:
# groud_truth = "2lnflow"
## Option 3:
# groud_truth = "pfBM"

# %% [markdown]
# #### Grid Hyperparameter(s)

# %%
## Monte-Carlo
N_Euler_Maruyama_Steps = 100
N_Monte_Carlo_Samples = 10**2
N_Monte_Carlo_Samples_Test = 10**3 # How many MC-samples to draw from test-set?

# End times for Time-Grid
T_end = 1
T_end_test = 1.1


## Grid
N_Grid_Finess = 100
Max_Grid = 0.5
x_0 = 1

# Number of Centers (\hat{\mu}_s)
N_Quantizers_to_parameterize = 10

# %% [markdown]
# This option sets $\delta$ in $B_{\mathbb{R}\times [0,\infty)}(\hat{x}_n,\delta)$; where $\hat{x}_n\in \nu_{\cdot}^{-1}[\hat{\mu}]$.  N_measures_per_center sets the number of samples to draw in this ball...by construction the training set is $\delta$-bounded and $\nu_{(x,t)}$, for any such $x$ is $\omega_{\nu_{\cdot}}(\delta)$-bounded in $\mathcal{P}_1(\mathbb{R})$.

# %%
# Hyper-parameters of Cover
delta = 0.1
N_measures_per_center = 100

# %% [markdown]
# **Note**: Setting *N_Quantizers_to_parameterize* prevents any barycenters and sub-sampling.

# %% [markdown]
# ### Random Cover
# This is not an active option!

# %%
# Set Minibatch Size
# Random_Cover_Mini_Batch_Size = 100

# %% [markdown]
# #### Mode: Code-Testin Parameter(s)
# - True: $\Rightarrow$ cross validation through grid of very mild parameters just to test hardward or software.
# - False: $\Rightarrow$ run CV-grid.

# %%
trial_run = True

# %% [markdown]
# ### Meta-parameters
# Ratio $\frac{\text{Testing Datasize}}{\text{Training Datasize}}$.

# %%
test_size_ratio = .25

# %% [markdown]
# ## Simulation from Rough SDE
# Simulate via Euler-M method from:
# $$
# X_T^x = x + \int_0^T \alpha(s,X_s^x)ds + \int_0^T((1-\eta)\beta(s,X_s^s)+\eta\sigma_s^H)dW_s.
# $$

# %% [markdown]
# ### Drift

# %%
def alpha(t,x):
    return .1*x#(.1-.5*(.01**2))*t #+ np.cos(x)

# %% [markdown]
# ### Volatility

# %%
def beta(t,x):
    return 0.01*x#+t*np.cos(x)

# %% [markdown]
# ### Roughness Meta-parameters
#  - Roughness is $H$,
#  - Ratio_fBM_to_typical_vol is $\eta$.

# %%
Rougness = 0.9 # Hurst Parameter
Ratio_fBM_to_typical_vol = 0 # $\eta$ in equation above.

# %% [markdown]
# ## Simulation from Measure-Valued $2$-Parameter Log-Gaussian Flow
# $$
# X_{t,x} \sim \log\text{-}\mathcal{N}\left(\alpha(t,x),\beta(t,x)\right).
# $$

# %% [markdown]
# **Note:** *$\alpha$ and $\beta$ are specified below in the SDE Example*.

# %%
# Run Backend
# %run Universal_Processes_Trainer_BACKEND.ipynb
exec(open('Universal_Processes_Trainer_BACKEND.py').read())
# Out:
# Using TensorFlow backend.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# Building Training + Testing Set - rough-SDE Ground-Truth
# 100%|██████████| 3/3 [00:00<00:00,  4.28it/s]
# Deep Feature Builder - Ready
# Deep Classifier - Ready
# ==========================================
# Training Classifer Portion of Type-A Model
# ==========================================
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    3.6s finished
# Epoch 1/50
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0558 - accuracy: 0.3422
# Epoch 2/50
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0332 - accuracy: 0.3867
# Epoch 3/50
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0148 - accuracy: 0.5200
# Epoch 4/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9969 - accuracy: 0.6667
# Epoch 5/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9797 - accuracy: 0.6667
# Epoch 6/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.9644 - accuracy: 0.6667
# Epoch 7/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9496 - accuracy: 0.6667
# Epoch 8/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9351 - accuracy: 0.6667
# Epoch 9/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9213 - accuracy: 0.6622
# Epoch 10/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9065 - accuracy: 0.6622
# Epoch 11/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8925 - accuracy: 0.6844
# Epoch 12/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8798 - accuracy: 0.6756
# Epoch 13/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8679 - accuracy: 0.6444
# Epoch 14/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8552 - accuracy: 0.6578
# Epoch 15/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8426 - accuracy: 0.6667
# Epoch 16/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8313 - accuracy: 0.6667
# Epoch 17/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8190 - accuracy: 0.6667
# Epoch 18/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8053 - accuracy: 0.6800
# Epoch 19/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7914 - accuracy: 0.7111
# Epoch 20/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7784 - accuracy: 0.7200
# Epoch 21/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7643 - accuracy: 0.7289
# Epoch 22/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7507 - accuracy: 0.7689
# Epoch 23/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7363 - accuracy: 0.8133
# Epoch 24/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7232 - accuracy: 0.8356
# Epoch 25/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7095 - accuracy: 0.8311
# Epoch 26/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6967 - accuracy: 0.8311
# Epoch 27/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.8489
# Epoch 28/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6719 - accuracy: 0.8756
# Epoch 29/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6610 - accuracy: 0.8978
# Epoch 30/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6502 - accuracy: 0.9111
# Epoch 31/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6372 - accuracy: 0.9289
# Epoch 32/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6233 - accuracy: 0.9156
# Epoch 33/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6096 - accuracy: 0.8800
# Epoch 34/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5985 - accuracy: 0.8489
# Epoch 35/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.8578
# Epoch 36/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5746 - accuracy: 0.8622
# Epoch 37/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5629 - accuracy: 0.8711
# Epoch 38/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5511 - accuracy: 0.8933
# Epoch 39/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5402 - accuracy: 0.8978
# Epoch 40/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.9067
# Epoch 41/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5187 - accuracy: 0.9156
# Epoch 42/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5082 - accuracy: 0.9333
# Epoch 43/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4977 - accuracy: 0.9422
# Epoch 44/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4879 - accuracy: 0.9467
# Epoch 45/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.9289
# Epoch 46/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4688 - accuracy: 0.9289
# Epoch 47/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.9244
# Epoch 48/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.9244
# Epoch 49/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.9244
# Epoch 50/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.9289
# 8/8 [==============================] - 0s 945us/step
# 3/3 [==============================] - 0s 1ms/step
# 100%|██████████| 3/3 [00:00<00:00, 1249.05it/s]
# 100%|██████████| 3/3 [00:00<00:00, 4078.74it/s]
#   0%|          | 0/224 [00:00<?, ?it/s]
# =================================================
# Training Classifer Portion of Type-A Model: Done!
# =================================================
# #---------------------------------------#
# Building Training Set (Regression): START
# #---------------------------------------#
# #-------------------------------------#
# Building Training Set (Regression): END
# #-------------------------------------#
# #-------------------------------------#
# Building Test Set (Predictions): START
# #-------------------------------------#
# #-----------------------------------#
# Building Test Set (Predictions): END
# #-----------------------------------#
# #-----------------------------#
# Building Barycenters Set: START
# #-----------------------------#
# #-----------------------------#
# Building Barycenters Set: END
# #-----------------------------#
# Building Training Set Performance Metrics
# 100%|██████████| 224/224 [00:00<00:00, 2453.48it/s]
#   0%|          | 0/75 [00:00<?, ?it/s]
# Building Test Set Performance Metrics
# 100%|██████████| 75/75 [00:00<00:00, 2046.91it/s]
# #----------------------#
# Training-Set Performance
# #----------------------#
#            W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  0.018822    0.000774             0.000067                0.413822
# MAE  0.043718    0.081730             0.027118                0.597100
# Max  0.079817    0.169131             0.084061                0.771451
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.569398
# MAE              0.725444
# Max              0.894953
#
#
#
# #------------------#
# Test-Set Performance
# #------------------#
#            W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  0.018822    0.002727             0.000229                0.430184
# MAE  0.043812    0.082020             0.027078                0.596534
# Max  0.079817    0.169131             0.084061                0.771451
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.571058
# MAE              0.724073
# Max              0.894953

# %% [markdown]
# # Visualization
# *From hereon out...do nothing and just let the backend sript run...the images and tables will load :).*

# %%
# Run Backend
# %run Universal_Processes_Trainer_Visuals.ipynb
exec(open('Universal_Processes_Trainer_Visuals.py').read())
# Out:
# Visualization of Training-Set Performance
# No handles with labels found to put in legend.
# Visualizing Training Predictions vs. Ground-Truth (Training Set)
# No handles with labels found to put in legend.
# Visualization of Test-Set Performance
# Visualizing Training Predictions vs. Ground-Truth (Testing Set)
# Visualizing Predictions Erros (Training Set)
# Visualizing Predictions Erros (Test Set)

# %% [markdown]
# ## Update User

# %% [markdown]
# ### Training-Set Performance

# %%
Type_A_Prediction
# Out:
#            W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  0.018822    0.000774             0.000067                0.413822
# MAE  0.043718    0.081730             0.027118                0.597100
# Max  0.079817    0.169131             0.084061                0.771451
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.569398
# MAE              0.725444
# Max              0.894953

# %% [markdown]
# ### Test-Set Performance

# %%
Type_A_Prediction_test
# Out:
#            W1  E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  0.018822    0.002727             0.000229                0.430184
# MAE  0.043812    0.082020             0.027078                0.596534
# Max  0.079817    0.169131             0.084061                0.771451
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.571058
# MAE              0.724073
# Max              0.894953

# %% [markdown]
# ---

# %%
predicted_paths = np.vstack(measures_locations_list)
predicted_paths_test = np.vstack(measures_locations_test_list)

# Initialize Plot #
#-----------------#
plt.figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

for i in range(10):
    plt.plot(predicted_paths[ i , : ] )

# Format Plot #
#-------------#
plt.title("Noise Example")

# Export #
#--------#
# SAVE Figure to .eps
plt.savefig('./outputs/plots/Example_Noise_at_arbitrary_point.pdf', format='pdf')

# %%
predicted_paths = np.vstack(measures_locations_list)
predicted_paths_test = np.vstack(measures_locations_test_list)

predicted_paths = np.vstack(measures_locations_list)
predicted_paths_test = np.vstack(measures_locations_test_list)

# Initialize Plot #
#-----------------#
plt.figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

for i in range(10):
    plt.plot(predicted_paths[ :50 :,i ] )

# Format Plot #
#-------------#
plt.title("Paths Example")

# Export #
#--------#
# SAVE Figure to .eps
plt.savefig('./outputs/plots/Example_paths.pdf', format='pdf')

# %% [markdown]
# ---
# # Fin
# ---

# %% [markdown]
# ---
