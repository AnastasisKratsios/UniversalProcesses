# %% [markdown]
# # Generic Conditional Laws for Random-Fields - via:
#
# ## Universal $\mathcal{P}_1(\mathbb{R})$-Deep Neural Model (Type A)
#
# ---
#
# By: [Anastasis Kratsios](https://people.math.ethz.ch/~kratsioa/) - 2021.
#
# ---

# %% [markdown]
# ---
# # Training Algorithm:
# ---
# ## 1) Generate Data:
# Generates the empirical measure $\sum_{n=1}^N \delta_{X_T(\omega_n)}$ of $X_T$ conditional on $X_0=x_0\in \mathbb{R}$ *($x_0$ and $T>0$ are user-provided)*.
#
# ## 2) Get "Sample Barycenters":
# Let $\{\mu_n\}_{n=1}^N\subset\mathcal{P}_1(\mathbb{R}^d)$.  Then, the *sample barycenter* is defined by:
# 1. $\mathcal{M}^{(0)}\triangleq \left\{\hat{\mu}_n\right\}_{n=1}^N$,
# 2. For $1\leq n\leq \mbox{N sample barycenters}$:
#     - $
# \mu^{\star}\in \underset{\tilde{\mu}\in \mathcal{M}^{(n)}}{\operatorname{argmin}}\, \sum_{n=1}^N \mathcal{W}_1\left(\mu^{\star},\mu_n\right),
# $
#     - $\mathcal{M}^{(n)}\triangleq \mathcal{M}^{(n-1)} - \{\mu^{\star}\},$
# *i.e., the closest generated measure form the random sample to all other elements of the random sample.*
#
# ---
# **Note:** *We simplify the computational burden of getting the correct classes by putting this right into this next loop.*
#
# ## 3) Train Deep Classifier:
# $\hat{f}\in \operatorname{argmin}_{f \in \mathcal{NN}_{d:N}^{\star}}
# \sum_{x \in \mathbb{X}}
# \,
# \mathbb{H}
# \left(
#     \operatorname{Softmax}_N\circ f(x)_n| I\left\{W_1(\hat{\mu}_n,\mu_x),\inf_{m\leq N} W_1(\hat{\mu}_m,\mu_x)\right\}
# \right);
# $
# where $\mathbb{H}$ is the categorical cross-entropy.
#
# ---
# ---
# ---
# ## Notes - Why the procedure is so computationally efficient?
# ---
#  - The sample barycenters do not require us to solve for any new Wasserstein-1 Barycenters; which is much more computationally costly,
#  - Our training procedure never back-propages through $\mathcal{W}_1$ since steps 2 and 3 are full-decoupled.  Therefore, training our deep classifier is (comparatively) cheap since it takes values in the standard $N$-simplex.
#
# ---

# %% [markdown]
# ## Meta-Parameters

# %% [markdown]
# ### Simulation

# %% [markdown]
# #### Ground Truth:
# *The build-in Options:*
# - rSDE
# - pfBM
# - 2lnflow

# %%
# Option 1:
# groud_truth = "rSDE"
# Option 2:
# groud_truth = "2lnflow"
## Option 3:
# groud_truth = "pfBM"

# %% [markdown]
# #### Grid Hyperparameter(s)

# %%
# ## Monte-Carlo
# N_Euler_Maruyama_Steps = 100
# N_Monte_Carlo_Samples = 10**2
# N_Monte_Carlo_Samples_Test = 10**3 # How many MC-samples to draw from test-set?

# # End times for Time-Grid
# T_end = 1
# T_end_test = 1.1


# ## Grid
# N_Grid_Finess = 100
# Max_Grid = 1

# # Number of Centers (\hat{\mu}_s)
# N_Quantizers_to_parameterize = 10

# %% [markdown]
# This option sets $\delta$ in $B_{\mathbb{R}\times [0,\infty)}(\hat{x}_n,\delta)$; where $\hat{x}_n\in \nu_{\cdot}^{-1}[\hat{\mu}]$.  N_measures_per_center sets the number of samples to draw in this ball...by construction the training set is $\delta$-bounded and $\nu_{(x,t)}$, for any such $x$ is $\omega_{\nu_{\cdot}}(\delta)$-bounded in $\mathcal{P}_1(\mathbb{R})$.

# %%
# # Hyper-parameters of Cover
# delta = 0.1
# N_measures_per_center = 100

# %% [markdown]
# **Note**: Setting *N_Quantizers_to_parameterize* prevents any barycenters and sub-sampling.

# %% [markdown]
# ### Random Cover
# This is not an active option!

# %%
# Set Minibatch Size
# Random_Cover_Mini_Batch_Size = 100

# %% [markdown]
# #### Mode: Code-Testin Parameter(s)
# - True: $\Rightarrow$ cross validation through grid of very mild parameters just to test hardward or software.
# - False: $\Rightarrow$ run CV-grid.

# %%
# trial_run = True

# %% [markdown]
# ### Meta-parameters
# Ratio $\frac{\text{Testing Datasize}}{\text{Training Datasize}}$.

# %%
# test_size_ratio = .25

# %% [markdown]
# ## Simulation from Rough SDE
# Simulate via Euler-M method from:
# $$
# X_T^x = x + \int_0^T \alpha(s,X_s^x)ds + \int_0^T((1-\eta)\beta(s,X_s^s)+\eta\sigma_s^H)dW_s.
# $$

# %% [markdown]
# ### Drift

# %%
# def alpha(t,x):
#     return .1*(.1-.5*(.01**2))*t #+ np.cos(x)

# %% [markdown]
# ### Volatility

# %%
# def beta(t,x):
#     return 0.01#+t*np.cos(x)

# %% [markdown]
# ### Roughness Meta-parameters
#  - Roughness is $H$,
#  - Ratio_fBM_to_typical_vol is $\eta$.

# %%
# Rougness = 0.9 # Hurst Parameter
# Ratio_fBM_to_typical_vol = 0 # $\eta$ in equation above.

# %% [markdown]
# ## Simulation from Measure-Valued $2$-Parameter Log-Gaussian Flow
# $$
# X_{t,x} \sim \log\text{-}\mathcal{N}\left(\alpha(t,x),\beta(t,x)\right).
# $$

# %% [markdown]
# **Note:** *$\alpha$ and $\beta$ are specified below in the SDE Example*.

# %%
# def field_dirction_x(x):
#     return x*np.cos(x)

# def finite_variation_t(t):
#     return t*(np.sin(math.pi*t) + np.exp(-t))

# %%
# Run Backend
# exec(open('Universal_Processes_Trainer_BACKEND_Simulation_Based_Method.py').read())

# %% [markdown]
# # INDEV-END

# %% [markdown]
# ### Get Paths

# %%
# load dataset
results_path = "./outputs/models/"
results_tables_path = "./outputs/results/"
raw_data_path_folder = "./inputs/raw/"
data_path_folder = "./inputs/data/"

# %% [markdown]
# ### Import

# %%
# Load Packages/Modules
exec(open('Init_Dump.py').read())
# Load Hyper-parameter Grid
exec(open('CV_Grid.py').read())
# Load Helper Function(s)
exec(open('Helper_Functions.py').read())
# Import time separately
import time
# Out:
# Using TensorFlow backend.
# Deep Feature Builder - Ready
# Deep Classifier - Ready

# %% [markdown]
# ### Set Seed

# %%
random.seed(2021)
np.random.seed(2021)
tf.random.set_seed(2021)

# %% [markdown]
# ## Get Internal (Hyper)-Parameter(s)
# *Initialize the hyperparameters which are fully-specified by the user-provided hyperparameter(s).*

# %% [markdown]
# ## Initialization of Auxiliary Internal-Variable(s)

# %%
# Initialize (Empirical) Weight(s)
measure_weights = np.ones(N_Monte_Carlo_Samples)/N_Monte_Carlo_Samples
measure_weights_test = np.ones(N_Monte_Carlo_Samples_Test)/N_Monte_Carlo_Samples_Test

# Get number of centers
N_Centers_per_box = max(1,int(round(np.sqrt(N_Quantizers_to_parameterize))))

# %% [markdown]
# ## Get Centers Grid

# %% [markdown]
# Get x and t grid of "centers".

# %% [markdown]
# #### Build Coordinates Grid
#
# *We separate the case of a $2$-parameter measure-valued flow from the SDE example as follows:*

# %%
# Generate Grid of Barycenters
x_Grid_barycenters = np.arange(start=(-Max_Grid+x_0),
                               stop=(Max_Grid+x_0),
                               step = (2*Max_Grid/N_Centers_per_box))
if groud_truth == "2lnflow":
    t_Grid_barycenters = np.arange(start=0,
                                   stop=T_end,
                                   step = (T_end/N_Centers_per_box))

# %% [markdown]
# **Note:** If we do not consider the 2-paramter (probability) measure-valued flow model; then we start all time points at the same place; so as to ensure that the "test set" consists exactly of future times corresponding to trained initial states!

# %%
if not(groud_truth == "2lnflow"):
    t_Grid_barycenters = np.arange(start=0,
                               stop=T_end,
                               step = 1)

# %% [markdown]
# #### Build Full-Grid

# %%
for x_i in range(len(x_Grid_barycenters)):
    for t_j in range(len(t_Grid_barycenters)):
        new_grid_entry = np.array([t_Grid_barycenters[t_j],x_Grid_barycenters[x_i]]).reshape(1,-1)
        if (x_i==0 and t_j ==0):
            Grid_Barycenters = new_grid_entry
        else:
            Grid_Barycenters = np.append(Grid_Barycenters,new_grid_entry,axis=0)

# Update Number of Quantizers Generated
N_Quantizers_to_parameterize = Grid_Barycenters.shape[0]

# %% [markdown]
# ### Generate Data
# This is $\mathbb{X}$ and it represents the grid of initial states.

# %%
# LOAD Simulator (Backend)
# %run Simulator.ipynb
exec(open('Simulator.py').read())

# %% [markdown]
# #### Start Timer (Model Type A)

# %%
# Start Timer
Type_A_timer_Begin = time.time()

# %% [markdown]
# ## $2$-Parameter $\log$-Gaussian Flow
# Generate data by sampling from a random-field $(X_t^x)_{t,x}$ distributed according to:
# $$
# X_{t,x} \sim \log\text{-}\mathcal{N}\left(\alpha(t,x),\beta(t,x)\right).
# $$
#
# ### Get Training Data

# %%
if groud_truth == "2lnflow":
    print("Building Training Set - 2-logNormal Ground-Truth")
    # Generate Training Data
    for i in tqdm(range(Grid_Barycenters.shape[0])):
        # Get output for center (mu-hat)
        center_current, trash = twoparameter_flow_sampler((Grid_Barycenters[i]).reshape(1,2),N_Monte_Carlo_Samples)

        # Get random sample in delta ball around ith center
        sub_grid_loop = np.random.uniform(0,delta,(N_measures_per_center,2)) + Grid_Barycenters[i]

        # Get Measures for this random sample
        measures_locations_list_current, measures_weights_list_current = twoparameter_flow_sampler(sub_grid_loop,N_Monte_Carlo_Samples)
        ##
        measures_locations_list_current = measures_locations_list_current + center_current
        measures_weights_list_current = measures_weights_list_current + trash
        # Update Classes
        Classifer_Wasserstein_Centers_loop = np.zeros([(N_measures_per_center+1),N_Quantizers_to_parameterize]) # The +1 is to account for the center which will be added to the random ball
        Classifer_Wasserstein_Centers_loop[:, i] =  1
        # Updates Classes
        if i==0:
            # INITIALIZE: Classifiers
            Classifer_Wasserstein_Centers = Classifer_Wasserstein_Centers_loop
            # INITIALIZE: Training Data
            X_train = np.append((Grid_Barycenters[i]).reshape(1,2),sub_grid_loop,axis=0)
            # INITIALIZE: Barycenters Array
            Barycenters_Array = (center_current[0]).reshape(-1,1)
            # INITIALIZE: Measures and locations
            measures_locations_list = measures_locations_list_current
            measures_weights_list = measures_weights_list_current
        else:
            # UPDATE: Classifer
            Classifer_Wasserstein_Centers = np.append(Classifer_Wasserstein_Centers,Classifer_Wasserstein_Centers_loop,axis=0)
            # UPDATE: Training Data
            X_train = np.append(X_train,np.append((Grid_Barycenters[i]).reshape(1,2),sub_grid_loop,axis=0),axis=0)
            # UPDATE: Populate Barycenters Array
            Barycenters_Array = np.append(Barycenters_Array,((center_current[0]).reshape(-1,1)),axis=-1)
            # UPDATE: Measures and locations
            measures_locations_list = measures_locations_list + measures_locations_list_current
            measures_weights_list = measures_locations_list + measures_weights_list_current
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 447.00it/s]
# Building Training Set - 2-logNormal Ground-Truth

# %% [markdown]
# ### Get Testing Data

# %%
if groud_truth == "2lnflow":
    print("Building Test Set - 2-logNormal Ground-Truth")
    # Generate Testing Dataset (Inputs)
    x_tests = np.random.uniform(np.min(X_train[:,0]),np.max(X_train[:,0]),10)
    t_tests = np.arange(start=0,
                        stop=T_end,
                        step = (T_end_test/N_Euler_Maruyama_Steps))
    for x_i in tqdm(range(len(x_tests))):
        for t_j in range(len(t_tests)):
            test_set_entry = np.array([t_tests[t_j],x_tests[x_i]]).reshape(1,-1)
            if (x_i==0 and t_j ==0):
                X_test = test_set_entry
            else:
                X_test = np.append(X_test,test_set_entry,axis=0)

    # Generate Testing Dataset (Outputs)
    measures_locations_test_list, measures_weights_test_list = twoparameter_flow_sampler(X_test,N_Monte_Carlo_Samples_Test)
# Out:
# Building Test Set - 2-logNormal Ground-Truth
# 100%|██████████| 10/10 [00:00<00:00, 649.23it/s]

# %% [markdown]
# ### Rough SDE:
# Simulation of the random-field:
# $$
# X_t^x = x + \int_0^t \alpha(s,X_t^x)ds + (1-\eta)\int_0^t \beta(s,X_t^x)dW_t + \int_0^t B_s^H dW_s;
# $$
# where:
#  - $(B_t^H)_t$ is a [fractional Brownian Motion](https://arxiv.org/pdf/1406.1956.pdf) with [Hurst exponent](https://en.wikipedia.org/wiki/Hurst_exponent) $H\in (0,1)$,
#  - $(W_t)_t$ is a [Brownian Motion](https://en.wikipedia.org/wiki/Wiener_process),
#  - $\alpha$ and $\beta$ are uniformly [Lipschitz-functions](https://en.wikipedia.org/wiki/Lipschitz_continuity) of appropriate input/output dimension.

# %% [markdown]
# ### Get Training and Testing Data

# %%
# LOAD Simulator (Backend)
# %run Simulator.ipynb
exec(open('Simulator.py').read())

# %%
# NEW?
if groud_truth == "rSDE":
    print("Building Training + Testing Set - rough-SDE Ground-Truth")
    
    # Initialize position Counter
    position_counter = 0
    # Iniitalize uniform weights vector
    measures_weights_list_loop = np.ones(N_Monte_Carlo_Samples)/N_Monte_Carlo_Samples

    # For simplicity override:
    N_Monte_Carlo_Samples_Test = N_Monte_Carlo_Samples
    
    # Overrine Number of Centers
    N_x = len(x_Grid_barycenters)
    N_t = len(t_Grid_barycenters)
    N_Quantizers_to_parameterize = N_x*N_t
    
    # Initialize number of training and testing to grab from each initial condition
    N_train = int(N_Euler_Maruyama_Steps*(1-test_size_ratio))
    N_test = N_Euler_Maruyama_Steps - N_train

    for x_i in tqdm(range(N_x)):
        for t_j in range(N_t):

            # Get Current Locations
            x_center = x_Grid_barycenters[x_i]
            t_center = t_Grid_barycenters[t_j]

            current_cover = Euler_Maruyama_Generator(x_0 = x_center,
                                                     N_Euler_Maruyama_Steps = N_Euler_Maruyama_Steps,
                                                     N_Monte_Carlo_Samples = N_Monte_Carlo_Samples,
                                                     T_begin = t_center,
                                                     T_end = (t_center+delta),
                                                     Hurst = Rougness,
                                                     Ratio_fBM_to_typical_vol = Ratio_fBM_to_typical_vol)
            # Get Barycenter
            barycenter_at_current_location = current_cover[0,:]
            
            # Subset
            ## Measure Location(s)
            measures_locations_list_current_train = (current_cover[:N_train]).tolist()
            measures_locations_list_current_test = (current_cover[:-N_train]).tolist()
            ## Measure Weight(s)
            measures_weights_list_current = list(itertools.repeat(measures_weights_list_loop,N_Monte_Carlo_Samples))

            
            # Get Current Training Data Positions
            t_grid_current = (np.linspace(start=t_center,
                                          stop=(t_center+delta),
                                          num=N_Euler_Maruyama_Steps)).reshape(1,-1)
            x_grid_current = (x_center*np.ones(N_Euler_Maruyama_Steps)).reshape(1,-1)

            X_train_current = (np.append(x_grid_current,t_grid_current,axis=0)).T
            ## Subset
            X_train_updater = X_train_current[:N_train,:] # Get top of array (including center)
            X_test_updater = X_train_current[-N_test:,:] # Get bottom of array (exclusing center)

            # Get Current Classes
            Classifer_Wasserstein_Centers_loop = np.zeros([N_train,N_Quantizers_to_parameterize])
            Classifer_Wasserstein_Centers_loop[:, position_counter] =  1


            # Updates Classes
            if (x_i==0 and t_j==0):
                # INITIALIZE: Classifiers
                Classifer_Wasserstein_Centers = Classifer_Wasserstein_Centers_loop
                # INITIALIZE: Training Data
                X_train = X_train_updater
                X_test = X_test_updater
                # INITIALIZE: Barycenters Array
                Barycenters_Array = barycenter_at_current_location.reshape(-1,1)
                # INITIALIZE: Measures and locations
                measures_locations_list = measures_locations_list_current_train
                measures_locations_test_list = measures_locations_list_current_test
                measures_weights_list = measures_weights_list_current
                measures_weights_test_list = measures_weights_list_current
            else:
                # UPDATE: Classifer
                Classifer_Wasserstein_Centers = np.append(Classifer_Wasserstein_Centers,Classifer_Wasserstein_Centers_loop,axis=0)
                # UPDATE: Training Data
                X_train = np.append(X_train,X_train_updater,axis=0)
                X_test = np.append(X_test,X_test_updater,axis=0)
                # UPDATE: Populate Barycenters Array
                Barycenters_Array = np.append(Barycenters_Array,(barycenter_at_current_location.reshape(-1,1)),axis=-1)
                # UPDATE: Measures and locations
                ## Train
                measures_locations_list = measures_locations_list + measures_locations_list_current_train
                measures_weights_list = measures_locations_list + measures_weights_list_current
                ## Test
                measures_locations_test_list = measures_locations_test_list + measures_locations_list_current_test
                measures_weights_test_list = measures_locations_test_list + measures_weights_list_current

            # Update Position
            position_counter = position_counter + 1

# %% [markdown]
# ---

# %% [markdown]
# ### Train Deep Classifier

# %% [markdown]
# In this step, we train a deep (feed-forward) classifier:
# $$
# \hat{f}\triangleq \operatorname{Softmax}_N\circ W_J\circ \sigma \bullet \dots \sigma \bullet W_1,
# $$
# to identify which barycenter we are closest to.

# %% [markdown]
# Re-Load Grid and Redefine Relevant Input/Output dimensions in dictionary.

# %% [markdown]
# #### Train Deep Classifier

# %%
# Re-Load Hyper-parameter Grid
exec(open('CV_Grid.py').read())
# Re-Load Classifier Function(s)
exec(open('Helper_Functions.py').read())
# Out:
# Deep Feature Builder - Ready
# Deep Classifier - Ready

# %%
print("==========================================")
print("Training Classifer Portion of Type-A Model")
print("==========================================")

# Redefine (Dimension-related) Elements of Grid
param_grid_Deep_Classifier['input_dim'] = [2]
param_grid_Deep_Classifier['output_dim'] = [N_Quantizers_to_parameterize]

# Train simple deep classifier
predicted_classes_train, predicted_classes_test, N_params_deep_classifier = build_simple_deep_classifier(n_folds = CV_folds, 
                                                                                                        n_jobs = n_jobs, 
                                                                                                        n_iter = n_iter, 
                                                                                                        param_grid_in=param_grid_Deep_Classifier, 
                                                                                                        X_train = X_train, 
                                                                                                        y_train = Classifer_Wasserstein_Centers,
                                                                                                        X_test = X_test)

print("=================================================")
print("Training Classifer Portion of Type-A Model: Done!")
print("=================================================")
# Out:
# ==========================================
# Training Classifer Portion of Type-A Model
# ==========================================
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   14.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   14.3s finished
# Epoch 1/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0128 - accuracy: 0.3685
# Epoch 2/400
# 29/29 [==============================] - 0s 2ms/step - loss: 1.4995 - accuracy: 0.5963
# Epoch 3/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.9384 - accuracy: 0.7349
# Epoch 4/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5111 - accuracy: 0.9912
# Epoch 5/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2429 - accuracy: 1.0000
# Epoch 6/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 1.0000
# Epoch 7/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 8/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 9/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 10/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 11/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 12/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 13/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 14/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 15/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 16/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 17/400
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 18/400
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 19/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 20/400
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 21/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 22/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 23/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 24/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 25/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 26/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 27/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 28/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 29/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 30/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 31/400
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 32/400
# 29/29 [==============================] - 0s 2ms/step - loss: 9.8864e-04 - accuracy: 1.0000
# Epoch 33/400
# 29/29 [==============================] - 0s 2ms/step - loss: 9.2321e-04 - accuracy: 1.0000
# Epoch 34/400
# 29/29 [==============================] - 0s 2ms/step - loss: 8.6387e-04 - accuracy: 1.0000
# Epoch 35/400
# 29/29 [==============================] - 0s 2ms/step - loss: 8.0997e-04 - accuracy: 1.0000
# Epoch 36/400
# 29/29 [==============================] - 0s 2ms/step - loss: 7.6152e-04 - accuracy: 1.0000
# Epoch 37/400
# 29/29 [==============================] - 0s 2ms/step - loss: 7.1742e-04 - accuracy: 1.0000
# Epoch 38/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.7540e-04 - accuracy: 1.0000
# Epoch 39/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.3714e-04 - accuracy: 1.0000
# Epoch 40/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.0403e-04 - accuracy: 1.0000
# Epoch 41/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.7070e-04 - accuracy: 1.0000
# Epoch 42/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.4105e-04 - accuracy: 1.0000
# Epoch 43/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.1442e-04 - accuracy: 1.0000
# Epoch 44/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.8813e-04 - accuracy: 1.0000
# Epoch 45/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.6435e-04 - accuracy: 1.0000
# Epoch 46/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.4279e-04 - accuracy: 1.0000
# Epoch 47/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.2252e-04 - accuracy: 1.0000
# Epoch 48/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.0348e-04 - accuracy: 1.0000
# Epoch 49/400
# 29/29 [==============================] - 0s 2ms/step - loss: 3.8487e-04 - accuracy: 1.0000
# Epoch 50/400
# 29/29 [==============================] - 0s 2ms/step - loss: 3.6797e-04 - accuracy: 1.0000
# Epoch 51/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.5236e-04 - accuracy: 1.0000
# Epoch 52/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.3771e-04 - accuracy: 1.0000
# Epoch 53/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.2317e-04 - accuracy: 1.0000
# Epoch 54/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.1040e-04 - accuracy: 1.0000
# Epoch 55/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.9783e-04 - accuracy: 1.0000
# Epoch 56/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.8614e-04 - accuracy: 1.0000
# Epoch 57/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.7502e-04 - accuracy: 1.0000
# Epoch 58/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.6451e-04 - accuracy: 1.0000
# Epoch 59/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.5462e-04 - accuracy: 1.0000
# Epoch 60/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.4494e-04 - accuracy: 1.0000
# Epoch 61/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.3624e-04 - accuracy: 1.0000
# Epoch 62/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.2788e-04 - accuracy: 1.0000
# Epoch 63/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1963e-04 - accuracy: 1.0000
# Epoch 64/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1206e-04 - accuracy: 1.0000
# Epoch 65/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0457e-04 - accuracy: 1.0000
# Epoch 66/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9775e-04 - accuracy: 1.0000
# Epoch 67/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9096e-04 - accuracy: 1.0000
# Epoch 68/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8469e-04 - accuracy: 1.0000
# Epoch 69/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7851e-04 - accuracy: 1.0000
# Epoch 70/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7258e-04 - accuracy: 1.0000
# Epoch 71/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6719e-04 - accuracy: 1.0000
# Epoch 72/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6188e-04 - accuracy: 1.0000
# Epoch 73/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5680e-04 - accuracy: 1.0000
# Epoch 74/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5180e-04 - accuracy: 1.0000
# Epoch 75/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4709e-04 - accuracy: 1.0000
# Epoch 76/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4252e-04 - accuracy: 1.0000
# Epoch 77/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3829e-04 - accuracy: 1.0000
# Epoch 78/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3410e-04 - accuracy: 1.0000
# Epoch 79/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3012e-04 - accuracy: 1.0000
# Epoch 80/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2634e-04 - accuracy: 1.0000
# Epoch 81/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2276e-04 - accuracy: 1.0000
# Epoch 82/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1917e-04 - accuracy: 1.0000
# Epoch 83/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1569e-04 - accuracy: 1.0000
# Epoch 84/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1245e-04 - accuracy: 1.0000
# Epoch 85/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0947e-04 - accuracy: 1.0000
# Epoch 86/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0623e-04 - accuracy: 1.0000
# Epoch 87/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0325e-04 - accuracy: 1.0000
# Epoch 88/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0055e-04 - accuracy: 1.0000
# Epoch 89/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.7830e-05 - accuracy: 1.0000
# Epoch 90/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.5175e-05 - accuracy: 1.0000
# Epoch 91/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.2740e-05 - accuracy: 1.0000
# Epoch 92/400
# 29/29 [==============================] - 0s 2ms/step - loss: 9.0145e-05 - accuracy: 1.0000
# Epoch 93/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.7858e-05 - accuracy: 1.0000
# Epoch 94/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.5574e-05 - accuracy: 1.0000
# Epoch 95/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.3244e-05 - accuracy: 1.0000
# Epoch 96/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.1096e-05 - accuracy: 1.0000
# Epoch 97/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.9046e-05 - accuracy: 1.0000
# Epoch 98/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.7069e-05 - accuracy: 1.0000
# Epoch 99/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.5152e-05 - accuracy: 1.0000
# Epoch 100/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.3204e-05 - accuracy: 1.0000
# Epoch 101/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.1747e-05 - accuracy: 1.0000
# Epoch 102/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.9654e-05 - accuracy: 1.0000
# Epoch 103/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.7969e-05 - accuracy: 1.0000
# Epoch 104/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.6355e-05 - accuracy: 1.0000
# Epoch 105/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.4697e-05 - accuracy: 1.0000
# Epoch 106/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.3134e-05 - accuracy: 1.0000
# Epoch 107/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.1661e-05 - accuracy: 1.0000
# Epoch 108/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.0134e-05 - accuracy: 1.0000
# Epoch 109/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.8732e-05 - accuracy: 1.0000
# Epoch 110/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.7376e-05 - accuracy: 1.0000
# Epoch 111/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.5990e-05 - accuracy: 1.0000
# Epoch 112/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.4903e-05 - accuracy: 1.0000
# Epoch 113/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.3455e-05 - accuracy: 1.0000
# Epoch 114/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.2237e-05 - accuracy: 1.0000
# Epoch 115/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.1036e-05 - accuracy: 1.0000
# Epoch 116/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.9883e-05 - accuracy: 1.0000
# Epoch 117/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.8739e-05 - accuracy: 1.0000
# Epoch 118/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.7632e-05 - accuracy: 1.0000
# Epoch 119/400
# 29/29 [==============================] - 0s 2ms/step - loss: 4.6569e-05 - accuracy: 1.0000
# Epoch 120/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.5520e-05 - accuracy: 1.0000
# Epoch 121/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.4512e-05 - accuracy: 1.0000
# Epoch 122/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.3554e-05 - accuracy: 1.0000
# Epoch 123/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.2613e-05 - accuracy: 1.0000
# Epoch 124/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.1647e-05 - accuracy: 1.0000
# Epoch 125/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.0744e-05 - accuracy: 1.0000
# Epoch 126/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.9850e-05 - accuracy: 1.0000
# Epoch 127/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.9038e-05 - accuracy: 1.0000
# Epoch 128/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.8159e-05 - accuracy: 1.0000
# Epoch 129/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.7367e-05 - accuracy: 1.0000
# Epoch 130/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.6579e-05 - accuracy: 1.0000
# Epoch 131/400
# 29/29 [==============================] - 0s 2ms/step - loss: 3.5817e-05 - accuracy: 1.0000
# Epoch 132/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.5040e-05 - accuracy: 1.0000
# Epoch 133/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.4299e-05 - accuracy: 1.0000
# Epoch 134/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.3554e-05 - accuracy: 1.0000
# Epoch 135/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.2847e-05 - accuracy: 1.0000
# Epoch 136/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.2221e-05 - accuracy: 1.0000
# Epoch 137/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.1504e-05 - accuracy: 1.0000
# Epoch 138/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.0863e-05 - accuracy: 1.0000
# Epoch 139/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.0234e-05 - accuracy: 1.0000
# Epoch 140/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.9604e-05 - accuracy: 1.0000
# Epoch 141/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.9038e-05 - accuracy: 1.0000
# Epoch 142/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.8371e-05 - accuracy: 1.0000
# Epoch 143/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.7805e-05 - accuracy: 1.0000
# Epoch 144/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.7227e-05 - accuracy: 1.0000
# Epoch 145/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.6696e-05 - accuracy: 1.0000
# Epoch 146/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.6233e-05 - accuracy: 1.0000
# Epoch 147/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.5619e-05 - accuracy: 1.0000
# Epoch 148/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.5118e-05 - accuracy: 1.0000
# Epoch 149/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.4591e-05 - accuracy: 1.0000
# Epoch 150/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.4117e-05 - accuracy: 1.0000
# Epoch 151/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.3647e-05 - accuracy: 1.0000
# Epoch 152/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.3168e-05 - accuracy: 1.0000
# Epoch 153/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.2719e-05 - accuracy: 1.0000
# Epoch 154/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.2266e-05 - accuracy: 1.0000
# Epoch 155/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1834e-05 - accuracy: 1.0000
# Epoch 156/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1397e-05 - accuracy: 1.0000
# Epoch 157/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0994e-05 - accuracy: 1.0000
# Epoch 158/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0566e-05 - accuracy: 1.0000
# Epoch 159/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0222e-05 - accuracy: 1.0000
# Epoch 160/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9802e-05 - accuracy: 1.0000
# Epoch 161/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9404e-05 - accuracy: 1.0000
# Epoch 162/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9028e-05 - accuracy: 1.0000
# Epoch 163/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8659e-05 - accuracy: 1.0000
# Epoch 164/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8293e-05 - accuracy: 1.0000
# Epoch 165/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7979e-05 - accuracy: 1.0000
# Epoch 166/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7612e-05 - accuracy: 1.0000
# Epoch 167/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7267e-05 - accuracy: 1.0000
# Epoch 168/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6932e-05 - accuracy: 1.0000
# Epoch 169/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6611e-05 - accuracy: 1.0000
# Epoch 170/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6310e-05 - accuracy: 1.0000
# Epoch 171/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6004e-05 - accuracy: 1.0000
# Epoch 172/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5701e-05 - accuracy: 1.0000
# Epoch 173/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5411e-05 - accuracy: 1.0000
# Epoch 174/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5131e-05 - accuracy: 1.0000
# Epoch 175/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4831e-05 - accuracy: 1.0000
# Epoch 176/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4562e-05 - accuracy: 1.0000
# Epoch 177/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4296e-05 - accuracy: 1.0000
# Epoch 178/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4032e-05 - accuracy: 1.0000
# Epoch 179/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3767e-05 - accuracy: 1.0000
# Epoch 180/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3507e-05 - accuracy: 1.0000
# Epoch 181/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3267e-05 - accuracy: 1.0000
# Epoch 182/400
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3015e-05 - accuracy: 1.0000
# Epoch 183/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2780e-05 - accuracy: 1.0000
# Epoch 184/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2541e-05 - accuracy: 1.0000
# Epoch 185/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2327e-05 - accuracy: 1.0000
# Epoch 186/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2083e-05 - accuracy: 1.0000
# Epoch 187/400
# 29/29 [==============================] - 0s 2ms/step - loss: 1.1861e-05 - accuracy: 1.0000
# Epoch 188/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1649e-05 - accuracy: 1.0000
# Epoch 189/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1443e-05 - accuracy: 1.0000
# Epoch 190/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1226e-05 - accuracy: 1.0000
# Epoch 191/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1035e-05 - accuracy: 1.0000
# Epoch 192/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0823e-05 - accuracy: 1.0000
# Epoch 193/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0631e-05 - accuracy: 1.0000
# Epoch 194/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0443e-05 - accuracy: 1.0000
# Epoch 195/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0262e-05 - accuracy: 1.0000
# Epoch 196/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0065e-05 - accuracy: 1.0000
# Epoch 197/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.8834e-06 - accuracy: 1.0000
# Epoch 198/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.7125e-06 - accuracy: 1.0000
# Epoch 199/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.5331e-06 - accuracy: 1.0000
# Epoch 200/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.3660e-06 - accuracy: 1.0000
# Epoch 201/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.1928e-06 - accuracy: 1.0000
# Epoch 202/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.0370e-06 - accuracy: 1.0000
# Epoch 203/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.8793e-06 - accuracy: 1.0000
# Epoch 204/400
# 29/29 [==============================] - 0s 2ms/step - loss: 8.7095e-06 - accuracy: 1.0000
# Epoch 205/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.5633e-06 - accuracy: 1.0000
# Epoch 206/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.4008e-06 - accuracy: 1.0000
# Epoch 207/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.2584e-06 - accuracy: 1.0000
# Epoch 208/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.1029e-06 - accuracy: 1.0000
# Epoch 209/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.9639e-06 - accuracy: 1.0000
# Epoch 210/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.8192e-06 - accuracy: 1.0000
# Epoch 211/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.6780e-06 - accuracy: 1.0000
# Epoch 212/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.5736e-06 - accuracy: 1.0000
# Epoch 213/400
# 29/29 [==============================] - 0s 2ms/step - loss: 7.4281e-06 - accuracy: 1.0000
# Epoch 214/400
# 29/29 [==============================] - 0s 2ms/step - loss: 7.2937e-06 - accuracy: 1.0000
# Epoch 215/400
# 29/29 [==============================] - 0s 2ms/step - loss: 7.1656e-06 - accuracy: 1.0000
# Epoch 216/400
# 29/29 [==============================] - 0s 2ms/step - loss: 7.0398e-06 - accuracy: 1.0000
# Epoch 217/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.9145e-06 - accuracy: 1.0000
# Epoch 218/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.7942e-06 - accuracy: 1.0000
# Epoch 219/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.6771e-06 - accuracy: 1.0000
# Epoch 220/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.5574e-06 - accuracy: 1.0000
# Epoch 221/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.4441e-06 - accuracy: 1.0000
# Epoch 222/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.3327e-06 - accuracy: 1.0000
# Epoch 223/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.2258e-06 - accuracy: 1.0000
# Epoch 224/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.1207e-06 - accuracy: 1.0000
# Epoch 225/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.0100e-06 - accuracy: 1.0000
# Epoch 226/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.9035e-06 - accuracy: 1.0000
# Epoch 227/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.8066e-06 - accuracy: 1.0000
# Epoch 228/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.7040e-06 - accuracy: 1.0000
# Epoch 229/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.6087e-06 - accuracy: 1.0000
# Epoch 230/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.5135e-06 - accuracy: 1.0000
# Epoch 231/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.4170e-06 - accuracy: 1.0000
# Epoch 232/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.3182e-06 - accuracy: 1.0000
# Epoch 233/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.2273e-06 - accuracy: 1.0000
# Epoch 234/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.1420e-06 - accuracy: 1.0000
# Epoch 235/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.0508e-06 - accuracy: 1.0000
# Epoch 236/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.9686e-06 - accuracy: 1.0000
# Epoch 237/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.8858e-06 - accuracy: 1.0000
# Epoch 238/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.8037e-06 - accuracy: 1.0000
# Epoch 239/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.7224e-06 - accuracy: 1.0000
# Epoch 240/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.6418e-06 - accuracy: 1.0000
# Epoch 241/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.5590e-06 - accuracy: 1.0000
# Epoch 242/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.4822e-06 - accuracy: 1.0000
# Epoch 243/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.4057e-06 - accuracy: 1.0000
# Epoch 244/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.3391e-06 - accuracy: 1.0000
# Epoch 245/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.2547e-06 - accuracy: 1.0000
# Epoch 246/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.1867e-06 - accuracy: 1.0000
# Epoch 247/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.1147e-06 - accuracy: 1.0000
# Epoch 248/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.0535e-06 - accuracy: 1.0000
# Epoch 249/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.9757e-06 - accuracy: 1.0000
# Epoch 250/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.9101e-06 - accuracy: 1.0000
# Epoch 251/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.8464e-06 - accuracy: 1.0000
# Epoch 252/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.7786e-06 - accuracy: 1.0000
# Epoch 253/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.7183e-06 - accuracy: 1.0000
# Epoch 254/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.6623e-06 - accuracy: 1.0000
# Epoch 255/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.5945e-06 - accuracy: 1.0000
# Epoch 256/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.5342e-06 - accuracy: 1.0000
# Epoch 257/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.4725e-06 - accuracy: 1.0000
# Epoch 258/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.4160e-06 - accuracy: 1.0000
# Epoch 259/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.3634e-06 - accuracy: 1.0000
# Epoch 260/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.2969e-06 - accuracy: 1.0000
# Epoch 261/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.2485e-06 - accuracy: 1.0000
# Epoch 262/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.1932e-06 - accuracy: 1.0000
# Epoch 263/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.1436e-06 - accuracy: 1.0000
# Epoch 264/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.0832e-06 - accuracy: 1.0000
# Epoch 265/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.0345e-06 - accuracy: 1.0000
# Epoch 266/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.9839e-06 - accuracy: 1.0000
# Epoch 267/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.9337e-06 - accuracy: 1.0000
# Epoch 268/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.8850e-06 - accuracy: 1.0000
# Epoch 269/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.8367e-06 - accuracy: 1.0000
# Epoch 270/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.7877e-06 - accuracy: 1.0000
# Epoch 271/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.7477e-06 - accuracy: 1.0000
# Epoch 272/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.7059e-06 - accuracy: 1.0000
# Epoch 273/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.6509e-06 - accuracy: 1.0000
# Epoch 274/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.6112e-06 - accuracy: 1.0000
# Epoch 275/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.5686e-06 - accuracy: 1.0000
# Epoch 276/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.5224e-06 - accuracy: 1.0000
# Epoch 277/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.4854e-06 - accuracy: 1.0000
# Epoch 278/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.4404e-06 - accuracy: 1.0000
# Epoch 279/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.4021e-06 - accuracy: 1.0000
# Epoch 280/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.3604e-06 - accuracy: 1.0000
# Epoch 281/400
# 29/29 [==============================] - 0s 2ms/step - loss: 2.3227e-06 - accuracy: 1.0000
# Epoch 282/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.2884e-06 - accuracy: 1.0000
# Epoch 283/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.2456e-06 - accuracy: 1.0000
# Epoch 284/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.2111e-06 - accuracy: 1.0000
# Epoch 285/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1736e-06 - accuracy: 1.0000
# Epoch 286/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1416e-06 - accuracy: 1.0000
# Epoch 287/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.1034e-06 - accuracy: 1.0000
# Epoch 288/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0688e-06 - accuracy: 1.0000
# Epoch 289/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0355e-06 - accuracy: 1.0000
# Epoch 290/400
# 29/29 [==============================] - 0s 1ms/step - loss: 2.0024e-06 - accuracy: 1.0000
# Epoch 291/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9715e-06 - accuracy: 1.0000
# Epoch 292/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9341e-06 - accuracy: 1.0000
# Epoch 293/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.9010e-06 - accuracy: 1.0000
# Epoch 294/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8718e-06 - accuracy: 1.0000
# Epoch 295/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8424e-06 - accuracy: 1.0000
# Epoch 296/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.8091e-06 - accuracy: 1.0000
# Epoch 297/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7804e-06 - accuracy: 1.0000
# Epoch 298/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7534e-06 - accuracy: 1.0000
# Epoch 299/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7224e-06 - accuracy: 1.0000
# Epoch 300/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.7003e-06 - accuracy: 1.0000
# Epoch 301/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6689e-06 - accuracy: 1.0000
# Epoch 302/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6363e-06 - accuracy: 1.0000
# Epoch 303/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.6123e-06 - accuracy: 1.0000
# Epoch 304/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5893e-06 - accuracy: 1.0000
# Epoch 305/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5624e-06 - accuracy: 1.0000
# Epoch 306/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5404e-06 - accuracy: 1.0000
# Epoch 307/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.5121e-06 - accuracy: 1.0000
# Epoch 308/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4881e-06 - accuracy: 1.0000
# Epoch 309/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4642e-06 - accuracy: 1.0000
# Epoch 310/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4411e-06 - accuracy: 1.0000
# Epoch 311/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4150e-06 - accuracy: 1.0000
# Epoch 312/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3926e-06 - accuracy: 1.0000
# Epoch 313/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3682e-06 - accuracy: 1.0000
# Epoch 314/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3479e-06 - accuracy: 1.0000
# Epoch 315/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3251e-06 - accuracy: 1.0000
# Epoch 316/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3057e-06 - accuracy: 1.0000
# Epoch 317/400
# 29/29 [==============================] - 0s 2ms/step - loss: 1.2872e-06 - accuracy: 1.0000
# Epoch 318/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2663e-06 - accuracy: 1.0000
# Epoch 319/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2453e-06 - accuracy: 1.0000
# Epoch 320/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2254e-06 - accuracy: 1.0000
# Epoch 321/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.2068e-06 - accuracy: 1.0000
# Epoch 322/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1837e-06 - accuracy: 1.0000
# Epoch 323/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1666e-06 - accuracy: 1.0000
# Epoch 324/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1489e-06 - accuracy: 1.0000
# Epoch 325/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1284e-06 - accuracy: 1.0000
# Epoch 326/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.1108e-06 - accuracy: 1.0000
# Epoch 327/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0926e-06 - accuracy: 1.0000
# Epoch 328/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0731e-06 - accuracy: 1.0000
# Epoch 329/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0588e-06 - accuracy: 1.0000
# Epoch 330/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0402e-06 - accuracy: 1.0000
# Epoch 331/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0249e-06 - accuracy: 1.0000
# Epoch 332/400
# 29/29 [==============================] - 0s 1ms/step - loss: 1.0069e-06 - accuracy: 1.0000
# Epoch 333/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.9393e-07 - accuracy: 1.0000
# Epoch 334/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.7702e-07 - accuracy: 1.0000
# Epoch 335/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.5866e-07 - accuracy: 1.0000
# Epoch 336/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.4436e-07 - accuracy: 1.0000
# Epoch 337/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.2941e-07 - accuracy: 1.0000
# Epoch 338/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.1367e-07 - accuracy: 1.0000
# Epoch 339/400
# 29/29 [==============================] - 0s 1ms/step - loss: 9.0043e-07 - accuracy: 1.0000
# Epoch 340/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.8272e-07 - accuracy: 1.0000
# Epoch 341/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.7118e-07 - accuracy: 1.0000
# Epoch 342/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.5715e-07 - accuracy: 1.0000
# Epoch 343/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.4351e-07 - accuracy: 1.0000
# Epoch 344/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.2961e-07 - accuracy: 1.0000
# Epoch 345/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.1492e-07 - accuracy: 1.0000
# Epoch 346/400
# 29/29 [==============================] - 0s 1ms/step - loss: 8.0365e-07 - accuracy: 1.0000
# Epoch 347/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.9263e-07 - accuracy: 1.0000
# Epoch 348/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.7978e-07 - accuracy: 1.0000
# Epoch 349/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.6522e-07 - accuracy: 1.0000
# Epoch 350/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.5460e-07 - accuracy: 1.0000
# Epoch 351/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.4148e-07 - accuracy: 1.0000
# Epoch 352/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.3086e-07 - accuracy: 1.0000
# Epoch 353/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.1775e-07 - accuracy: 1.0000
# Epoch 354/400
# 29/29 [==============================] - 0s 1ms/step - loss: 7.0686e-07 - accuracy: 1.0000
# Epoch 355/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.9349e-07 - accuracy: 1.0000
# Epoch 356/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.8326e-07 - accuracy: 1.0000
# Epoch 357/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.7040e-07 - accuracy: 1.0000
# Epoch 358/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.5978e-07 - accuracy: 1.0000
# Epoch 359/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.4785e-07 - accuracy: 1.0000
# Epoch 360/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.3762e-07 - accuracy: 1.0000
# Epoch 361/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.2739e-07 - accuracy: 1.0000
# Epoch 362/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.1965e-07 - accuracy: 1.0000
# Epoch 363/400
# 29/29 [==============================] - 0s 1ms/step - loss: 6.0903e-07 - accuracy: 1.0000
# Epoch 364/400
# 29/29 [==============================] - 0s 2ms/step - loss: 6.0103e-07 - accuracy: 1.0000
# Epoch 365/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.9054e-07 - accuracy: 1.0000
# Epoch 366/400
# 29/29 [==============================] - 0s 2ms/step - loss: 5.8228e-07 - accuracy: 1.0000
# Epoch 367/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.7283e-07 - accuracy: 1.0000
# Epoch 368/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.6378e-07 - accuracy: 1.0000
# Epoch 369/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.5618e-07 - accuracy: 1.0000
# Epoch 370/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.4634e-07 - accuracy: 1.0000
# Epoch 371/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.3703e-07 - accuracy: 1.0000
# Epoch 372/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.2706e-07 - accuracy: 1.0000
# Epoch 373/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.1854e-07 - accuracy: 1.0000
# Epoch 374/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.1054e-07 - accuracy: 1.0000
# Epoch 375/400
# 29/29 [==============================] - 0s 1ms/step - loss: 5.0254e-07 - accuracy: 1.0000
# Epoch 376/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.9533e-07 - accuracy: 1.0000
# Epoch 377/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.8667e-07 - accuracy: 1.0000
# Epoch 378/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.8012e-07 - accuracy: 1.0000
# Epoch 379/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.7303e-07 - accuracy: 1.0000
# Epoch 380/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.6543e-07 - accuracy: 1.0000
# Epoch 381/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.5599e-07 - accuracy: 1.0000
# Epoch 382/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.5048e-07 - accuracy: 1.0000
# Epoch 383/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.4182e-07 - accuracy: 1.0000
# Epoch 384/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.3422e-07 - accuracy: 1.0000
# Epoch 385/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.2753e-07 - accuracy: 1.0000
# Epoch 386/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.2136e-07 - accuracy: 1.0000
# Epoch 387/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.1454e-07 - accuracy: 1.0000
# Epoch 388/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.0720e-07 - accuracy: 1.0000
# Epoch 389/400
# 29/29 [==============================] - 0s 1ms/step - loss: 4.0169e-07 - accuracy: 1.0000
# Epoch 390/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.9435e-07 - accuracy: 1.0000
# Epoch 391/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.8845e-07 - accuracy: 1.0000
# Epoch 392/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.8189e-07 - accuracy: 1.0000
# Epoch 393/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.7625e-07 - accuracy: 1.0000
# Epoch 394/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.7035e-07 - accuracy: 1.0000
# Epoch 395/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.6563e-07 - accuracy: 1.0000
# Epoch 396/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.5986e-07 - accuracy: 1.0000
# Epoch 397/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.5409e-07 - accuracy: 1.0000
# Epoch 398/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.4832e-07 - accuracy: 1.0000
# Epoch 399/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.4320e-07 - accuracy: 1.0000
# Epoch 400/400
# 29/29 [==============================] - 0s 1ms/step - loss: 3.3809e-07 - accuracy: 1.0000
# 29/29 [==============================] - 0s 647us/step
# 29/29 [==============================] - 0s 663us/step
# =================================================
# Training Classifer Portion of Type-A Model: Done!
# =================================================

# %% [markdown]
# #### Get Predicted Quantized Distributions
# - Each *row* of "Predicted_Weights" is the $\beta\in \Delta_N$.
# - Each *Column* of "Barycenters_Array" denotes the $x_1,\dots,x_N$ making up the points of the corresponding empirical measures.

# %%
# Format Weights
## Train
print("#---------------------------------------#")
print("Building Training Set (Regression): START")
print("#---------------------------------------#")
Predicted_Weights = np.array([])
for i in tqdm(range(N_Quantizers_to_parameterize)):    
    b = np.repeat(np.array(predicted_classes_train[:,i],dtype='float').reshape(-1,1),N_Monte_Carlo_Samples,axis=-1)
    b = b/N_Monte_Carlo_Samples
    if i ==0 :
        Predicted_Weights = b
    else:
        Predicted_Weights = np.append(Predicted_Weights,b,axis=1)
print("#-------------------------------------#")
print("Building Training Set (Regression): END")
print("#-------------------------------------#")

## Test
print("#-------------------------------------#")
print("Building Test Set (Predictions): START")
print("#-------------------------------------#")
Predicted_Weights_test = np.array([])
for i in tqdm(range(N_Quantizers_to_parameterize)):
    b_test = np.repeat(np.array(predicted_classes_test[:,i],dtype='float').reshape(-1,1),N_Monte_Carlo_Samples,axis=-1)
    b_test = b_test/N_Monte_Carlo_Samples
    if i ==0 :
        Predicted_Weights_test = b_test
    else:
        Predicted_Weights_test = np.append(Predicted_Weights_test,b_test,axis=1)
print("#-----------------------------------#")
print("Building Test Set (Predictions): END")
print("#-----------------------------------#")
        
# Format Points of Mass
print("#-----------------------------#")
print("Building Barycenters Set: START")
print("#-----------------------------#")
Barycenters_Array = Barycenters_Array.T.reshape(-1,)
print("#-----------------------------#")
print("Building Barycenters Set: END")
print("#-----------------------------#")
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# #---------------------------------------#
# Building Training Set (Regression): START
# #---------------------------------------#
# 100%|██████████| 9/9 [00:00<00:00, 381.80it/s]
# 100%|██████████| 9/9 [00:00<00:00, 703.66it/s]
# #-------------------------------------#
# Building Training Set (Regression): END
# #-------------------------------------#
# #-------------------------------------#
# Building Test Set (Predictions): START
# #-------------------------------------#
# #-----------------------------------#
# Building Test Set (Predictions): END
# #-----------------------------------#
# #-----------------------------#
# Building Barycenters Set: START
# #-----------------------------#
# #-----------------------------#
# Building Barycenters Set: END
# #-----------------------------#

# %% [markdown]
# #### Stop Timer

# %%
# Stop Timer
Type_A_timer_end = time.time()
# Compute Lapsed Time Needed For Training
Time_Lapse_Model_A = Type_A_timer_end - Type_A_timer_Begin

# %% [markdown]
# ## Get Moment Predictions

# %% [markdown]
# #### Write Predictions

# %% [markdown]
# ### Training-Set Result(s):

# %%
print("Building Training Set Performance Metrics")

# Initialize Wasserstein-1 Error Distribution
W1_errors = np.array([])
Mean_errors = np.array([])
Var_errors = np.array([])
Skewness_errors = np.array([])
Kurtosis_errors = np.array([])
predictions_mean = np.array([])
true_mean = np.array([])
#---------------------------------------------------------------------------------------------#

# Populate Error Distribution
for x_i in tqdm(range(len(measures_locations_list)-1)):    
    # Get Laws
    W1_loop = ot.emd2_1d(Barycenters_Array,
                         np.array(measures_locations_list[x_i]).reshape(-1,),
                         Predicted_Weights[x_i,].reshape(-1,),
                         (np.array(measures_weights_list[x_i])).reshape(-1,))
    W1_errors = np.append(W1_errors,W1_loop)
    # Get Means
    Mu_hat = np.sum((Predicted_Weights[x_i])*(Barycenters_Array))
    Mu = np.mean(np.array(measures_locations_list[x_i]))
    Mean_errors =  np.append(Mean_errors,(Mu_hat-Mu))
    ## Update Erros
    predictions_mean = np.append(predictions_mean,Mu_hat)
    true_mean = np.append(true_mean,Mu)
    # Get Var (non-centered)
    Var_hat = np.sum((Barycenters_Array**2)*(Predicted_Weights[x_i]))
    Var = np.mean(np.array(measures_locations_list[x_i])**2)
    Var_errors = np.append(Var_errors,(Var_hat-Var)**2)
    # Get skewness (non-centered)
    Skewness_hat = np.sum((Barycenters_Array**3)*(Predicted_Weights[x_i]))
    Skewness = np.mean(np.array(measures_locations_list[x_i])**3)
    Skewness_errors = np.append(Skewness_errors,(abs(Skewness_hat-Skewness))**(1/3))
    # Get skewness (non-centered)
    Kurtosis_hat = np.sum((Barycenters_Array**4)*(Predicted_Weights[x_i]))
    Kurtosis = np.mean(np.array(measures_locations_list[x_i])**4)
    Kurtosis_errors = np.append(Kurtosis_errors,(abs(Kurtosis_hat-Kurtosis))**.25)
    
#---------------------------------------------------------------------------------------------#
W1_95 = bootstrap(W1_errors, n=1000, func=np.mean)(.95)
W1_99 = bootstrap(W1_errors, n=1000, func=np.mean)(.99)
M_95 = bootstrap(predictions_mean, n=1000, func=np.mean)(.95)
M_99 = bootstrap(predictions_mean, n=1000, func=np.mean)(.99)
M_95_MC = bootstrap(true_mean, n=1000, func=np.mean)(.95)
M_99_MC = bootstrap(true_mean, n=1000, func=np.mean)(.99)
#---------------------------------------------------------------------------------------------#
# Compute Error Statistics/Descriptors
W1_Performance = np.array([np.min(np.abs(W1_errors)),np.mean(np.abs(W1_errors)),np.max(np.abs(W1_errors))])
Mean_prediction_Performance = np.array([np.min(np.abs(Mean_errors)),np.mean(np.abs(Mean_errors)),np.max(np.abs(Mean_errors))])
Var_prediction_Performance = np.array([np.min(np.abs(Var_errors)),np.mean(np.abs(Var_errors)),np.max(np.abs(Var_errors))])
Skewness_prediction_Performance = np.array([np.min(np.abs(Skewness_errors)),np.mean(np.abs(Skewness_errors)),np.max(np.abs(Skewness_errors))])
Kurtosis_prediction_Performance = np.array([np.min(np.abs(Kurtosis_errors)),np.mean(np.abs(Kurtosis_errors)),np.max(np.abs(Kurtosis_errors))])

Type_A_Prediction = pd.DataFrame({"W1":W1_Performance,
                                  "E[X']-E[X]":Mean_prediction_Performance,
                                  "(E[X'^2]-E[X^2])^.5":Var_prediction_Performance,
                                  "(E[X'^3]-E[X^3])^(1/3)":Skewness_prediction_Performance,
                                  "(E[X'^4]-E[X^4])^.25":Kurtosis_prediction_Performance},index=["Min","MAE","Max"])
Type_A_Predictions_and_confidence = pd.DataFrame({"W1_99_Train":W1_95,
                                                  "W1error_99_Train":W1_99,
                                                  "M_95_Train":M_95,
                                                  "M_99_Train":M_99,
                                                  "MC_95_Train":M_95_MC,
                                                  "MC_99_Train":M_99_MC},index=["CL","Mean","CU"])


# Write Performance
Type_A_Prediction.to_latex((results_tables_path+str("Roughness_")+str(Rougness)+str("__RatiofBM_")+str(Ratio_fBM_to_typical_vol)+
 "__TypeAPrediction_Train.tex"))

Type_A_Predictions_and_confidence.to_latex((results_tables_path+str("Roughness_")+str(Rougness)+str("__RatiofBM_")+str(Ratio_fBM_to_typical_vol)+
 "__TypeAPrediction_Train_predictions_w_confidence_intervals.tex"))

#---------------------------------------------------------------------------------------------#
# Update User
Type_A_Prediction
# Out:
#   0%|          | 0/908 [00:00<?, ?it/s]
# Building Training Set Performance Metrics
# 100%|██████████| 908/908 [00:00<00:00, 2073.67it/s]
#            W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  0.000289  1.333451e-08         1.780656e-16                0.002373
# MAE  0.000724  1.095624e-03         7.750032e-06                0.137072
# Max  0.002313  4.208876e-03         7.109525e-05                0.233128
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.010753
# MAE              0.239594
# Max              0.360690

# %% [markdown]
# ---

# %% [markdown]
# ### Test-Set Result(s):

# %%
print("Building Test Set Performance Metrics")

# Initialize Wasserstein-1 Error Distribution
W1_errors_test = np.array([])
Mean_errors_test = np.array([])
Var_errors_test = np.array([])
Skewness_errors_test = np.array([])
Kurtosis_errors_test = np.array([])
# Initialize Prediction Metrics
predictions_mean_test = np.array([])
true_mean_test = np.array([])
#---------------------------------------------------------------------------------------------#

# Populate Error Distribution
for x_i in tqdm(range(len(measures_locations_test_list))):    
    # Get Laws
    W1_loop_test = ot.emd2_1d(Barycenters_Array,
                         np.array(measures_locations_test_list[x_i]).reshape(-1,),
                         Predicted_Weights_test[x_i,].reshape(-1,),
                         (np.array(measures_weights_test_list[x_i])).reshape(-1,))
    W1_errors_test = np.append(W1_errors_test,W1_loop_test)
    # Get Means
    Mu_hat_test = np.sum((Predicted_Weights_test[x_i])*(Barycenters_Array))
    Mu_test = np.mean(np.array(measures_locations_test_list[x_i]))
    Mean_errors_test = np.append(Mean_errors_test,(Mu_hat_test-Mu_test))
    ## Update Predictions
    predictions_mean_test = np.append(predictions_mean_test,Mu_hat_test)
    true_mean_test = np.append(true_mean_test,Mu_test)
    # Get Var (non-centered)
    Var_hat_test = np.sum((Barycenters_Array**2)*(Predicted_Weights_test[x_i]))
    Var_test = np.mean(np.array(measures_locations_test_list[x_i])**2)
    Var_errors_test = np.append(Var_errors_test,(Var_hat_test-Var_test)**2)
    # Get skewness (non-centered)
    Skewness_hat_test = np.sum((Barycenters_Array**3)*(Predicted_Weights_test[x_i]))
    Skewness_test = np.mean(np.array(measures_locations_test_list[x_i])**3)
    Skewness_errors_test = np.append(Skewness_errors_test,(abs(Skewness_hat_test-Skewness_test))**(1/3))
    # Get skewness (non-centered)
    Kurtosis_hat_test = np.sum((Barycenters_Array**4)*(Predicted_Weights_test[x_i]))
    Kurtosis_test = np.mean(np.array(measures_locations_test_list[x_i])**4)
    Kurtosis_errors_test = np.append(Kurtosis_errors_test,(abs(Kurtosis_hat_test-Kurtosis_test))**.25)
    
#---------------------------------------------------------------------------------------------#
W1_95_test = bootstrap(W1_errors_test, n=1000, func=np.mean)(.95)
W1_99_test = bootstrap(W1_errors_test, n=1000, func=np.mean)(.99)
M_95_test = bootstrap(predictions_mean_test, n=1000, func=np.mean)(.95)
M_99_test = bootstrap(predictions_mean_test, n=1000, func=np.mean)(.99)
M_95_MC_test = bootstrap(true_mean_test, n=1000, func=np.mean)(.95)
M_99_MC_test = bootstrap(true_mean_test, n=1000, func=np.mean)(.99)
#---------------------------------------------------------------------------------------------#
# Compute Error Statistics/Descriptors
W1_Performance_test = np.array([np.min(np.abs(W1_errors_test)),np.mean(np.abs(W1_errors_test)),np.max(np.abs(W1_errors_test))])
Mean_prediction_Performance_test = np.array([np.min(np.abs(Mean_errors_test)),np.mean(np.abs(Mean_errors_test)),np.max(np.abs(Mean_errors_test))])
Var_prediction_Performance_test = np.array([np.min(np.abs(Var_errors_test)),np.mean(np.abs(Var_errors_test)),np.max(np.abs(Var_errors_test))])
Skewness_prediction_Performance_test = np.array([np.min(np.abs(Skewness_errors_test)),np.mean(np.abs(Skewness_errors_test)),np.max(np.abs(Skewness_errors_test))])
Kurtosis_prediction_Performance_test = np.array([np.min(np.abs(Kurtosis_errors_test)),np.mean(np.abs(Kurtosis_errors_test)),np.max(np.abs(Kurtosis_errors_test))])

Type_A_Prediction_test = pd.DataFrame({"W1":W1_Performance_test,
                                  "E[X']-E[X]":Mean_prediction_Performance_test,
                                  "(E[X'^2]-E[X^2])^.5":Var_prediction_Performance_test,
                                  "(E[X'^3]-E[X^3])^(1/3)":Skewness_prediction_Performance_test,
                                  "(E[X'^4]-E[X^4])^.25":Kurtosis_prediction_Performance_test},index=["Min","MAE","Max"])
Type_A_Predictions_and_confidence_test = pd.DataFrame({"W1_99_Test":W1_95_test,
                                                       "W1error_99_Test":W1_99_test,
                                                       "M_95_Test":M_95_test,
                                                       "M_99_Test":M_99_test,
                                                       "MC_95_Test":M_95_MC_test,
                                                       "MC_99_Test":M_99_MC_test},index=["CL","Mean","CU"])

# Write Performance
Type_A_Prediction_test.to_latex((results_tables_path+str("Roughness_")+str(Rougness)+str("__RatiofBM_")+str(Ratio_fBM_to_typical_vol)+
 "__TypeAPrediction_Test.tex"))
Type_A_Predictions_and_confidence_test.to_latex((results_tables_path+str("Roughness_")+str(Rougness)+str("__RatiofBM_")+str(Ratio_fBM_to_typical_vol)+
 "__TypeAPrediction_Test_predictions_w_confidence_intervals.tex"))
# Out:
#   File "<ipython-input-2-ac8ebc0283b0>", line 67
#     "MC_99_Test":M_99_MC_test},index=["CL","MAE","CU])
#                                                       ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # Visualization

# %% [markdown]
# #### Visualization of Training-Set Performance

# %%
plt.plot(predictions_mean,label="prediction",color="purple")
plt.plot(true_mean,label="true",color="green")

# %%
# # plt.plot(predictions_mean_test,color="purple")
# # plt.plot(true_mean_test)

# # Initialize Plot #
# #-----------------#
# plt.figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

# # Generate Plots #
# #----------------#
# ax = plt.axes(projection='3d')
# ax.plot_trisurf(X_train[:-1:,0], X_train[:-1:,1], true_mean, cmap='viridis',linewidth=0.5);
# ax.plot_trisurf(X_train[:-1:,0], X_train[:-1:,1], predictions_mean, cmap='inferno',linewidth=0.5);


# # Format Plot #
# #-------------#
# plt.legend(loc="upper left",prop={'size': 10})
# plt.title("Model Predictions")

# # Export #
# #--------#
# # SAVE Figure to .eps
# plt.savefig('./outputs/plots/Test.pdf', format='pdf')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Visualization of Test-Set Performance

# %%
# # plt.plot(predictions_mean_test,color="purple")
# # plt.plot(true_mean_test)

# # sns.set()
# # Initialize Plot #
# #-----------------#
# plt.figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

# # Generate Plots #
# #----------------#
# ax = plt.axes(projection='3d')
# ax.plot_trisurf(X_test[:-1:,0], X_test[:-1:,1], true_mean_test, cmap='viridis',linewidth=0.5);
# ax.plot_trisurf(X_train[:-1:,0], X_train[:-1:,1], predictions_mean_test, cmap='inferno',linewidth=0.5);


# # Format Plot #
# #-------------#
# plt.legend(loc="upper left",prop={'size': 10})
# plt.title("Model Predictions")

# # Export #
# #--------#
# # SAVE Figure to .eps
# plt.savefig('./outputs/plots/Test.pdf', format='pdf')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Update User

# %% [markdown]
# ### Print for Terminal Legibility

# %%
print("#----------------------#")
print("Training-Set Performance")
print("#----------------------#")
print(Type_A_Prediction)
print(" ")
print(" ")
print(" ")

print("#------------------#")
print("Test-Set Performance")
print("#------------------#")
print(Type_A_Prediction_test)
print(" ")
print(" ")
print(" ")
# Out:
# #----------------------#
# Training-Set Performance
# #----------------------#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ae108de64326> in <module>
#       2 print("Training-Set Performance")
#       3 print("#----------------------#")
# ----> 4 print(Type_A_Prediction)
#       5 print(" ")
#       6 print(" ")
#
# NameError: name 'Type_A_Prediction' is not defined

# %% [markdown]
# ### Training-Set Performance

# %%
# Type_A_Prediction
# Out:
#            W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  0.000289  1.333451e-08         1.780656e-16                0.002373
# MAE  0.000724  1.095624e-03         7.750032e-06                0.137072
# Max  0.002313  4.208876e-03         7.109525e-05                0.233128
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.010753
# MAE              0.239594
# Max              0.360690

# %% [markdown]
# ### Test-Set Performance

# %%
# Type_A_Prediction_test
# Out:
#                W1    E[X']-E[X]  (E[X'^2]-E[X^2])^.5  (E[X'^3]-E[X^3])^(1/3)  \
# Min  4.162762e-07  9.307827e-08         2.114280e-12                0.016667
# MAE  5.384966e-06  1.398210e-03         1.242487e-05                0.150024
# Max  5.384966e-06  1.398210e-03         1.242487e-05                0.150024
#
#      (E[X'^4]-E[X^4])^.25
# Min              0.027573
# MAE              0.257011
# Max              0.257011

# %% [markdown]
# ---

# %% [markdown]
# ---
# # Fin
# ---

# %% [markdown]
# ---
